# %%
import json
import pandas as pd
from itertools import combinations
import Levenshtein
import numpy as np
from sklearn.cluster import DBSCAN

# %%
with open('data/przepisy.json') as f:
    recipes = json.load(f)

# %%
ingredients = []
for recipe in recipes:
    for ingredient in recipe['ingredient_list']:
        ingredients.append([ recipe['url'], ingredient['ingredient_name'], 
                            ingredient['ingredient_amount'],
                            ingredient['ingredient_unit']])

# %%
df = pd.DataFrame(ingredients, columns=["URL", "nazwa", "ilosc", "jednostka"])

# %%
df["nazwa"].head()
# Out:
# 0     makaron świderki
# 1    filet z kurczaka
# 2               cebula
# 3              papryka
# 4              pomidor
# Name: nazwa, dtype: object

# %%
names = df["nazwa"].unique()

# %%
pairs = combinations(enumerate(names), 2)
n_names = len(names)
distances = np.zeros((n_names, n_names))
for (index1, prod1), (index2, prod2) in pairs:
    distance = Levenshtein.distance(prod1, prod2) / max(len(prod1), len(prod2))
    distances[index1, index2] = distance
    distances[index2, index1] = distance

# %%
distances
# Out:
# array([[0.        , 0.88235294, 1.        , ..., 0.68      , 0.81818182,
#         0.86666667],
#        [0.88235294, 0.        , 0.82352941, ..., 0.8       , 0.81818182,
#         0.86666667],
#        [1.        , 0.82352941, 0.        , ..., 0.88      , 0.95454545,
#         0.86666667],
#        ...,
#        [0.68      , 0.8       , 0.88      , ..., 0.        , 0.52      ,
#         0.76666667],
#        [0.81818182, 0.81818182, 0.95454545, ..., 0.52      , 0.        ,
#         0.86666667],
#        [0.86666667, 0.86666667, 0.86666667, ..., 0.76666667, 0.86666667,
#         0.        ]])

# %%
clust = DBSCAN(eps=0.3, min_samples=2, metric='precomputed', n_jobs=-1)
clust.fit(distances)
# Out:
# DBSCAN(algorithm='auto', eps=0.3, leaf_size=30, metric='precomputed',
#        metric_params=None, min_samples=2, n_jobs=-1, p=None)

# %%
labels = clust.labels_
n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)
clusters = clust.labels_
for cluster_id in range(n_clusters):
    indexes, = np.where(labels == cluster_id)
    cluster_names = [names[i] for i in indexes.tolist()]
    print(f"Cluster {cluster_id}:\n({len(cluster_names)} produktów): {set(cluster_names)}\n" )
# Out:
# Cluster 0:
# (55 produktów): {'makaron chiński', 'makaron literki', 'makaron np: rurki', 'makaron macaroni', 'makaron spagetti', 'makaron np. świderki', 'makaron, np. świderki', 'makaron gniazda ', 'makaron krótki, np. świderki', 'makaron razowy', 'makaron sojowy ', 'makaron koraliki', 'makaron Rigatoni', 'makaron Bucatini', 'makaron ryżowy', 'makaron rurki', 'makaron gryczany', 'makaron muszelki', 'makaron orzo ', 'makaron udon', 'makaron drobny', 'makaron tortellini', 'makaron np. spaghetti', 'makaron orechiette', 'makaron spaghetti', 'makaron kokardki', 'makaron fusilli', 'makaron, np. penne', 'makaron penne', 'makaron Wonton', 'makaron typu Penne', 'makaron orecchiette ', 'makaron, np. rurki', 'makaron rigatoni', 'makaron typ muszelki', 'makaron diatali', 'makaron świderki', 'makaron gniazda nitki', 'makaron typu świderki', 'makaronowe rurki', 'makaron pennette', 'makaron gwiazdki', 'makaron pipette', 'makaron ryzowy', 'makaron wstążki', 'makaron duże muszle', 'makaron nitki', 'makaron, np. muszelki', 'makaron (duże muszle)', 'gotowy makaron cannelloni', 'makaron orkiszowy świderki', 'makaron cannelloni', 'makaron duże rurki', 'makaron soba', 'makaron uszka'}
#
# Cluster 1:
# (1410 produktów): {'posiekany czosnek', 'posiekana świeża bazylia', 'cebula czerwona posiekana', 'słodka papryka wędzona w proszku', 'ziemniaki obrane, pokrojone w plastry ', 'mięso z indyka pokrojone w kostkę ', 'fasolka czerwona', 'ziemniaki obrane ', 'szynka wieprzowa', 'ostra papryka do smaku', 'Ziemniaki duże', 'karkówka pokrojona w plastry', 'marchew (obrana i pokrojona w plastry)', 'soja ugotowana ', 'mięso mielone jagnięce', 'czerwona ostra papryczka', 'rostbef z kością ', 'ryż ugotowany ', 'udka, ćwiartki z kurczaka', 'pomidory krojone z puszki', 'poszatkowana biała kapusta', 'suszona papryka chilli', 'polędwiczka z dorsza', 'papryka wędzona', 'garść świeżej pietruszki', 'mięso mielone, np. drobiowe', 'gruszki suszone', 'kurczak mały', 'konserwowa papryka czerwona', 'mała zielona papryka ', 'marynowana papryka ze słoika', 'mała puszka czerwonej fasoli ', 'polędwiczki z sandacza', 'papryka słodka mielona', 'fasola puszka', 'papryczka chilli lub jalapeno', 'jajko ugotowane ', 'duży ziemniak ', 'pomidor pokrojony w kostkę', 'udka z kurczaka bez kości i skóry', 'piersi z kurczaka', 'grzyby leśne suszone', 'pomidor bez skórki', 'Cebulka prażona', 'natka pietruszki - 1 pęczek', 'grillowana czerwona papryka', 'Pietruszka pokrojona w kostkę', 'strąk ostrej papryki', 'czerwona ostra fasola', 'papryczki chili mulato ', 'Cebula (pokrojona w kostkę)', 'ser żółty pokrojony w małą kostkę', 'papryczka chilii', 'młode cebulki ', 'pieczarki duże ', 'ogórki korniszony', 'pomidorki koktajlowe pomarańczowe', 'mięso mielone jagnięce lub wołowe', 'szynka peklowana', 'czerwona fasola puszka', 'posiekany świeży imbir', 'pasta tahini', 'marchewka pokrojona w kostkę', 'cebula biała pokrojona w piórka', 'czerwona czubrica ', 'mielone mięso jagnięce (opcjonalnie)', 'mięso mielone z udźca indyka ', 'wędzone udko kurczaka', 'tuszki kurczaka', 'wędzony kurczak', 'czarna fasola z puszki', 'ugotowane piersi kurczaka ', 'papryka (czerwona, zielona lub żółta)', 'groszek konserwowy puszka', 'udka kurczaka bez kości', 'zielona oliwka', 'cebula czerwona (pokrojona w ćwiartki)', 'pierś z kurczaka ', 'mięso wołowe, np. steki z antrykota', 'kapary zielone', 'pomidory pelatti w puszce', 'mięso mielone wołowe', 'cały kurczak', 'Papryka czerwona duża', 'zielony ogórek', 'biała cebula', 'posiekana natki pietruszki ', 'ostra zielona papryczka', 'suszona papryczka piri-piri ', 'cebula, pokrojona w kostkę', 'pieczona pierś z kurczaka', 'Papryczka chilli suszona ', 'posiekana biała kapusta', 'mięso mielone jagnięce (opcjonalnie)', 'boczek wędzony pokrojony w kostkę', 'udko z kurczaka bez skóry i kości', 'papryka marynowana czerwona', '2 czerwone cebule', 'śliwki kwaszone ', 'zielona pietruszka posiekana ', 'podwójna pierś z kurczaka', 'nieduże ziemniaki', 'polędwica z sarny', 'posiekana mięta', 'siekana cebula', 'podudzie z kurczaka bez kości', 'biodro kurczaka', 'fasola czerwona puszka', 'filet z kaczki ', 'oliwki marynowane', 'schab wieprzowy bekonowy', 'cebula czerwona mała', 'upieczone podudzie z kurczaka', 'wieprzowe mięso mielone', 'papryka czerwona lub zielona', 'papryka chili', 'zielone chilli', 'Natka pietruszki posiekanej', 'konserwowa papryka', 'papryka czerwona (oczyszczona)', 'żółte papryki', 'mała pikantna papryczka ', 'mięso mielone kurczaka', 'wędzona pierś z kaczki', 'papryka chili zielona', 'strąk kolorowej papryki', 'mielone mięso z kurczaka', 'mięso mielone wieprzowe lub wołowe', 'mielone mięso (wieprzowe lub wołowe)', 'papryka zielona pokrojona w paski', 'udko kurczaka bez skóry ', 'szynka pieczona', 'migdały pokrojone w plastry', 'mięso z szynki wieprzowej', 'ziemniaki słodkie ', 'papryka mielona słodka', 'mięso mielone z udek kurczaka ', 'wędzone śliwki', 'młody ziemniak', 'papryka czerwona mielona słodka', 'Młoda cebulka', 'strąk papryki chili', 'buraki (małe)', 'słodka papryka w proszku', 'pomidory w puszce', 'mięso wołowe zrazówka', 'papryka różnokolorowa', 'mięso wołowe na zrazy', 'pieczarki średnie ', 'młode ziemniaki małe', 'koper zielon ...
#
# Cluster 2:
# (5 produktów): {'cebula', 'cebuli', 'cebule', 'cebulka', 'cebulki'}
#
# Cluster 3:
# (2 produktów): {'papryka', 'papryki'}
#
# Cluster 4:
# (7 produktów): {'pomidor', 'Pomidor ', 'Pomidor', 'pomidory', 'pomiodory', 'pomiodor ', '1 pomidor '}
#
# Cluster 5:
# (40 produktów): {'suszone pomidory z czosnkiem i bazylią', 'mały słoiczek koncentratu pomidorowego', 'suszone pomidory w małym słoiku', 'suszone pomidory w oleju', 'suszone pomidory w zalewie', '1 łyżka koncentratu pomidorowego', 'suszone pomidory z oliwy', 'suszone pomidory w oliwie ', 'mały koncentrat pomidorowy', 'koncentrat pomidorowy 30%', 'przecier pomidorowy mały słoik', '30% koncentrat pomidorowy', 'suszone pomidory z olejem', 'koncentrat pomidorowy słoiczek mały', 'przecier pomidorowy z kartonu', 'suszone pomidory (nie w zalewie)', 'słoiczki przecieru pomidorowego (małe)', 'mały przecier pomidorowy', 'puszka przecieru pomidorowego', 'suszone pomidory w oleju połówki', 'suszone pomidory mały słoik', 'przecieru pomidorowego', 'słoik przecieru pomidorowego', 'suszone pomidory (wraz z oliwą)', 'koncentrat pomidorowy', 'dobry koncentrat pomidorowy', 'Mała puszka koncentratu pomidorowego', 'koncentrat pomidorowy mały', 'suszone pomidory w płatkach', 'przecier pomidorowy w kartonie', 'suszone pomidory w zalewie olejowej', 'suszone pomidory w oliwie  z ziołami', 'przecier pomidorowy', 'suszone pomidory w oleju ', 'suszone pomidory na słońcu', 'koncentrat pomidorowy mała puszka ', 'puszka koncentratu pomidorowego', 'suszone pomidory z czosnkiem', 'przecier pomidorowy passata', 'przecier pomidorowy 30%'}
#
# Cluster 6:
# (35 produktów): {'zmiażdżony ząbek czosnku', 'roztarty ząbek czosnku', 'ząbki czosnku', 'Ząbek czonsku', 'posiekany ząbek czosnku', '4 posiekane ząbki czosnku', 'zmiażdżone ząbki czosnku', 'mała główka czosnku', 'kilka ząbków czosnku', '2 posiekane ząbki czosnku', 'duży ząbek czosnku', 'ząbki czosku', 'roztarte ząbki czosnku', 'malutki ząbek czosnku', 'mały ząbek czosnku', 'utarty ząbek czosnku ', '1 ząbek czosnku ', '3-4 ząbki czosnku', '1 ząbek czosnku', 'ząbków czosnku', '4 ząbki czosnku', 'ząbek czosnek', 'główki czosnku', 'zabek czosnku', 'cała główka czosnku', 'rozgnieciony ząbek czosnku', 'ząbki czoasnku', 'ząbek czosku', '1 posiekany ząbek czosnku', '1 mały posiekany ząbek czosnku', 'obrane ząbki czosnku ', 'rozgniecione ząbki czosnku', 'posiekane ząbki czosnku ', 'ząbek czosnku', 'główka czosnku'}
#
# Cluster 7:
# (41 produktów): {'plaster sera mozzarella light', 'gomółka sera mozzarella', 'starty ser mozzarella light', 'mozzarella bufala', 'ser mozzarella mini', 'starty ser mozzarella', 'mini mozzarella w kulkach ', 'ser mozzarella kulka', 'ser mozzarella, gomółka', 'ser mozzarella z serwatką', 'kulka sera mozzarella w zalewie', 'mozzarella w kulce', 'mozarella', 'tarta mozarella light', 'kulka sera mozzarella ', 'mozzarella w kulkach', 'kulka sera mozzarella light', 'ser mozzarella', 'ser mozarella', 'starta Mozzarella', 'mozarella kulki', 'mozzarella', 'starty ser np mozzarella', 'ser mozzarella kulka, starty', 'twardy ser mozzarella, starty', 'mozzarella w małych kulkach', 'mozarella w kulkach', 'ser mozzarella wędzona starty', 'mozzarella w zalewie', 'mozzarella w mini kulkach', 'mozarella light', 'ser mozzarella z bloku', 'ser mozzarella, starty', 'mozzarella (duże kulki)', 'mozzarella minikulki', 'mozzarella kulki', 'mozzarella, małe kulki', 'ser mozzarella light', 'tarta mozzarella', 'ser mozzarella kulki', 'ser mozzarella (starty)'}
#
# Cluster 8:
# (2 produktów): {'Olej', 'olej'}
#
# Cluster 9:
# (4 produktów): {'sola', 'Woda', 'soda', 'woda'}
#
# Cluster 10:
# (2 produktów): {'schab karkowy', 'schab środkowy'}
#
# Cluster 11:
# (26 produktów): {'ulubiona sałata', 'ulubione zioła', 'duże winne jabłko', 'winne jabłka', 'cienka kiełbasa pętko', 'nieduże kwaśne jabłko ', 'kwaśne jabłka', 'pikantna kiełbasa', 'ulubiona kiełbasa', 'białej kiełbasy', 'czerwone jabłko', 'duże kwaśne jabłko', 'suszone zioła', 'cienka kiełbasa', 'Twoje ulubione kiełki', 'kwaśne jabłko', 'suszone jabłka', 'ulubione kiełki', 'zielone jabłko', 'pętko białej kiełbasy', 'winne jabłko', 'twarde jabłka', 'ulubiona sałatka', 'cienkie kiełbaski', 'biała kiełbasa', 'zielone jabłka'}
#
# Cluster 12:
# (3 produktów): {'szalotki', 'szalotka', '1 szalotka'}
#
# Cluster 13:
# (2 produktów): {'ocet np. jabłkowy', 'ocet jabłkowy'}
#
# Cluster 14:
# (6 produktów): {'marchewki', 'marchew ', 'Marchewka', 'marchewka', 'marchewek', 'marchew'}
#
# Cluster 15:
# (41 produktów): {'ostry chrzan', 'starty ementaler', 'ser ementaler', 'starty ser gouda', 'starty ser parmezan', 'ser typu ementaler', 'starty ser gruyer', 'starty ser typu Gouda', 'ser (starty parmezan)', 'starty ser (np parmezan)', 'tarty parmezan', 'kostka sera feta', 'plastry sera', 'plastry sera feta', 'plastry ogórka', 'garść startego parmezanu', 'starty parmezan', 'starty ser np ementaler', 'starty ser Ementaler', 'utarty parmezan', 'starty ser (najlepiej Pecorino)', 'plasterki sera', 'tartego parmezanu', 'starty żółty ser typu Gouda', 'starty cheddar ', 'utarty chrzan ', 'tarty ser parmezan', 'ser topiony ementaler ', 'starty chrzan', 'starty ser (najlepiej parmezan)', 'starty ser żółty ementaler', 'ser tarty parmezan', 'starty ser, np. parmezan', 'starty ser cheddar', 'ser żółty ementaler', 'tarty chrzan', 'ser starty, np. parmezan', 'starty ser typu Gruyere', 'starty ser typu parmezan', 'plastry sera gouda', 'ser parmezan'}
#
# Cluster 16:
# (85 produktów): {'śmietana 26%', 'śmietana 8%', 'śmietana 36% UHT ', 'Śmietana UHT 36% ', 'śmietana 30%', 'śmietana 36% kwaśna', 'śmietanka słodka 36% UHT ', 'śmietana słodka', 'śmietana 18 %', 'smietana', 'gęsta śmietana 22%', 'śmietana 12 %', 'Śmietanka 36%', 'śmietana 36% - 50 ml', 'śmietanka 18%', 'śmietana 18% ', 'śmietanka 26%', 'smietan 18', 'kwaśna śmietana 18%', 'śmietana 36%', 'słodka śmietanka', 'śmietanka kremówka ', 'śmietana  12% ', 'śmietana 18% duża', 'śmietana 36% - 100 ml', 'gęsta kwaśna śmietana 30%', 'gęsta śmietana', 'gęsta, kwaśna śmietana', 'śmietana  36% ', 'śmietana 18% słodka', 'śmietana słodka 18%', 'kwaśna śmietana', 'kwaśna śmietana kremówka', 'śmietana słodka 30%', 'śmietanka słodka', 'gęsta śmietana 18% ', 'śmietana 30% kremówka', 'śmietana kremówka', 'śmietanka łodka 18%', 'kwaśna smietana', 'Śmietana  30%', 'śmietana UHT', 'słodka śmietanka 18%', 'słodka śmietanka 18 %', 'śmietana kwaśna gęsta', 'śmietanka 20%', 'śmietana mała', 'kwaśna śmietana 30%', 'słodka śmietanka kremówka', 'śmietanka 40 % ', 'śmietanka', 'śmietana 35%', 'słodka śmietanka 10 %', 'duża śmietana 18%', 'śmietana - 30 ml', 'kwaśna śmietana 12%', 'kwaśna śmietana 12-18 %', 'śmietana 18%', 'śmietanka 30%', 'śmietana gęsta kwaśna ', 'słodka śmietana', 'śmietana 18% mała ', 'śmietana 22 %', 'słodka śmietanka 30%', 'słodka śmietana 30%', 'śmietana 22%', 'śmietana kwaśna', 'śmietana  kwaśna 18%', 'śmietana 10%', 'śmietana kremówka 30%', 'słodka śmietana 12%', 'słodka śmietana 36%', 'śmietana kremowa ', 'śmietana kremówka 18%', 'śmietana 12%', 'śmietana', 'Śmietanka 12%', 'śmietana kremówka 36%', 'śmietana UHT 30%', 'słodka śmietana 18%', 'śmietana 12% mała', 'śmietana kremówka 30 %', 'śmietana 36 %', 'śmietana 30 %', 'gęsta kwaśna śmietana'}
#
# Cluster 17:
# (6 produktów): {'mąka pszenna', 'bułeczka pszenna ', 'Mąka pszenna', 'bułki pszenne ', 'bułka pszenna', 'mąka przenna'}
#
# Cluster 18:
# (9 produktów): {'jajo ', 'jajka', 'jajo', 'Jaja', '4 jajka', 'jajko', '3 jajka', '2 jajka', 'jaja'}
#
# Cluster 19:
# (2 produktów): {'olej roślinny', 'olej roslinny'}
#
# Cluster 20:
# (5 produktów): {'stary żółty ser', 'starty żółty ser', 'tarty żółty ser', 'ostry żółty ser ', 'tarty ostry ser'}
#
# Cluster 21:
# (7 produktów): {'mrożony kalafior', 'nieduży kalafior', 'zielony kalafior', 'duży kalafior', 'fioletowy kalafior', 'mały kalafior', 'cały kalafior'}
#
# Cluster 22:
# (5 produktów): {'tarty ser żółty', 'starty ostry ser żółty', 'starty ser żółty', 'ostry ser żółty', 'ostry starty ser żółty'}
#
# Cluster 23:
# (3 produktów): {'ziemniaków', 'ziemniaki', 'ziemniak'}
#
# Cluster 24:
# (6 produktów): {'jajka ugotowane na twardo', 'jajo gotowane na twardo', 'jaja ugotowane na twardo', 'jajka gotowane na twardo', 'jajko ugotowane na twardo', 'żółtka ugotowane na twardo '}
#
# Cluster 25:
# (3 produktów): {'surowe jajka', 'cukrowe jajka', 'surowe jajko'}
#
# Cluster 26:
# (22 produktów): {'Cebulki dymki', 'bułka pita', 'cebulka mała', 'cebule małe', 'cebula dymka', 'cebula biała nieduża ', 'cebula duża', 'bułka mała', 'bulka  tarta', 'cebule, średnie', 'cebule dymki', 'cebulka dymka', 'cebula mała', 'bułka tarta', '2 cebule białe', 'cebula biała, nieduża ', 'Cebule duże', 'cebula średnia ', 'cebula nieduża ', 'cebula biała', 'cebula, mała', 'cebule białe'}
#
# Cluster 27:
# (21 produktów): {'ziemniaki średniej wielkości', 'jabłka średniej wielkości', 'kapusta włoska (średniej wielkości)', 'słodkie ziemniaki średniej wielkości', 'kapusta średniej wielkości', 'kalarepa średniej wielkości', 'cebula średniej wielkości', 'piersi z kurczaka średniej wielkości', 'kabaczek średniej wielkości  ', 'bakłażan średniej wielkości', 'Pomidor (średniej wielkości)', 'kurczak średniej wielkości', 'marchewka średniej wielkości', 'seler średniej wielkości', 'cała dorada średniej wielkości', 'cukinia średniej wielkości ', 'karkówka średniej wielkości', 'buraki średniej wielkości', 'ziemniaki średniej wielkosci', 'brokuł średniej wielkości', 'cebula biała średniej wielkości '}
#
# Cluster 28:
# (2 produktów): {'oscypek', 'oscypki'}
#
# Cluster 29:
# (72 produktów): {'ser kozi w plastrach', 'ser  żółty tarty', 'ser żółty, np. cheddar', 'cytryna w plastrach', 'łosoś w plastrach', 'surowa szynka w plastrach', 'szynka plastry', 'ser żółty łagodny', 'ser zółty tarty', 'ser żółty salami', 'Chudy boczek wieprzowy surowy', 'ser żółty Masdamer', 'ser żółty starty ', 'szynka w dużych plastrach', 'salami w plasterkach', 'schab w plastrach', 'łosoś wędzony plastry', 'ser żółty ostry starty', 'ser topiony w plastrach gouda', 'boczek surowy w plastrach', 'ser salami w plastrach', 'ser żółty morski ', 'ser żółty - plastry', 'szynka konserwowa w plastrach', 'ser twardy np. gouda', 'ser zółty w plastrach', 'salami  w plastrach', 'szynka wędzona plastry', 'karkówka w plastrach', 'bekon w plasterkach', 'ser żółty, np. gouda', 'ser żółty w kostce ', 'ser żółty, starty', 'łosoś wędzony na zimno w plastrach', 'ser żółty(0,5cm plastry)', 'ser żółty (radamer)', 'ser żółty gouda', 'łosoś wędzony w plastrach ', 'ser żółty gouda plastry', 'szynka w plastrach', 'ser żółty w plasterkach', 'słonina w plasterkach', 'szynka parmeńska w plastrach', 'boczek wędzony surowy', 'słonina w plastrach', 'ser żółty, np. gruyère', 'boczek wieprzowy surowy', 'ser żółty tarty', 'boczek wędzony w plastrach', 'szynka wędzona w plastrach', 'boczek wędzony parzony', 'wołowina w plastrach', 'ser żółty plastry', 'ser żółty twardy', 'boczek wieprzowy parzony', 'ser żółty np. gruyère', 'ser topiony w plastrach ', 'ser żółty (starty) ', 'boczek w plastrach', 'ser żółty ostry ', 'szynka wędzona (grube plastry)', 'szynka babuni w plastrach', 'boczek - plasterki', 'ser żółty w plastrach', 'boczek wędzony - 8 plastrów', 'boczek wędzony bez skóry', 'ser żółty, najlepiej gruyere', 'szynka dojrzewająca w plastrach', 'boczek wędzony plastry', 'boczek plastry', 'gotowana szynka w plastrach', 'ser żółty cheddar'}
#
# Cluster 30:
# (2 produktów): {'chudy biały ser', 'tłusty biały ser'}
#
# Cluster 31:
# (61 produktów): {'otarta skórka i sok z 2 limonek', 'skórka i sok z limonki', 'sok z cyrtyny', 'soku z cytryny', 'sok z 1/3 cytryny', 'sok z 1/2 limonki', 'sok z jednej cytryny', 'otarta skórka z 1 limonki', 'sok z połówki cytryny', 'skórka z 1/2 cytryny', 'sok z połowy cytryny', 'otarta skórka z 2 limonek', 'skórka z 1 cytryny', 'sok z cytryn ', 'sok z  1 limonki', 'sok z limonek', 'sok z ½ cytryny', 'sok  z  cytryny', 'sok z 1 cytryny', 'sok z 3 limonek', 'starta skóra z cytryny', 'skórka starta z cytryny', 'sok z 1/2 cytryny', 'sok z  cytryny', 'sok z małej cytryny', 'skórka otarta z 1 cytryny', 'sok i starta skórka z 1 cytryny', 'Sok z 0.5 cytryny', 'skórka z połowy cytryny', 'otarta skórka z cytryny', 'starta skórka z limonki ', 'sok i skórka z cytryny', 'sok limonki', 'otarta skórka z 1 cytryny', 'sok z połowy limonki', 'skórka z limonki', 'sok z 2 cytryn', 'otarta skórka cytrynowa', 'sok z cytryny', 'starta skórka z cytryny', 'skórka z otartej cytryny', 'sok z limetki ', 'sok  z 1 cytryny', 'otarka skórka mandarynkowa', 'sok z 2 limonek', 'skórka otarta z limonki', 'sok z 1/4 cytryny', 'skórka otarta z połowy cytryny', 'otarta skórka z połowy cytryny', 'Listki limonki', 'sok z ćwiartki cytryny', 'skórka z cytryny', 'skórka otarta z jednej cytryny', 'sok z  1/4 cytryny', 'skórka otarta z cytryny', 'sok z 4 cytryn', 'skórka starta z limonki', 'starta skórka cytrynowa', 'sok z limonki', 'sok z 1 limonki', 'skórka starta z jednej cytryny '}
#
# Cluster 32:
# (2 produktów): {'siekany szczypiorek', 'posiekany szczypiorek'}
#
# Cluster 33:
# (31 produktów): {'kark wieprzowy', 'żeberka wędzone', 'karkówka wieprzowa', 'żeberka wieprzowe', 'wątróbka z królika', 'wątróbki drobiowe', 'jelita wieprzowe', 'watróbka wieprzowa', 'nerki wieprzowe', 'steki wieprzowe ', 'parówki drobiowe', 'pasztet wieprzowy', 'Wątróbka z kurczaka ', 'wątróbka z drobiu ', 'żeberka wołowe', 'wątróbka wieprzowa', 'kotlety wieprzowe', 'wątroba wołowa', 'ozorki wieprzowe ', 'karczek wieprzowy', 'karkówka wołowa', 'kość wieprzowa mała ', 'wątroba wieprzowa', 'kość wieprzowa', 'wątróbka z indyka', 'wątróbka wołowa ', 'wątróbka drobiowa', 'nóżki wieprzowe', 'Kości wieprzowe', 'karkówka cała', 'karkówka wieprzowina'}
#
# Cluster 34:
# (3 produktów): {'mąka', 'Mąka', 'mąka '}
#
# Cluster 35:
# (18 produktów): {'tłuszcz do pieczenia', 'smalec do smażenia', 'olej do pieczenia', 'woreczek do pieczenia', 'mąka do zasmażki', 'oliwa do smażenia', 'olej (do smażenia)', 'margaryna do smażenia', 'masło do polania', 'tłuszcz do smażenia', 'tłuszcz do smażenia ', 'olej do smażenia', 'rama do smażenia', 'masło do zasmażki', 'proszek do pieczenia', 'papier do pieczenia', 'Proszek do pieczenia', 'masło do smażenia'}
#
# Cluster 36:
# (75 produktów): {'cytryna do dekoracji', 'gęsta śmietana do dekoracji', 'kwaśna śmietana do podania', 'świeże bratki do dekoracji', 'koperek kilka gałązek do dekoracji', 'kilka gałązek kopru do ogórków', 'mięta kilka listków', 'gałązka natki do dekoracji', 'rzodkiewka do dekoracji', 'świeża kolendra', 'tymianek do dekoracji', 'świeża kolendra natka', 'świeże zioła do dekoracji', 'świeży tymianek do podania', 'świeża mięta do dekoracji', 'świeża szałwia posiekana', 'świeża mięta gałązka', 'koperek gałązki do dekoracji', 'bazylia do dekoracji', 'gałązka świeżego rozmarynu do dekoracji', 'kawałek papryki do dekoracji', 'mięta świeża kilka listków', 'kwaśna śmietana do dekoracji', 'listek świeżej bazylii do dekoracji', 'marchewka do dekoracji', 'rukola, kilka listków', 'cytryna cała (do dekoracji)', 'liście szałwii do dekoracji', 'koperek do dekoracji', 'świeża kolendra (posiekana)', 'świeży tymianek do dekoracji', 'liście bazylii do dekoracji', 'kilka gałązek koperku do dekoracji', 'kiełki lucerny do dekoracji', 'świeża mięta (posiekana)', 'świeża szałwia gałązka', 'świeża bazylia gałązki', 'gałązka rozmarynu do dekoracji', 'świeża bazylia, listki', 'świeża bazylia, posiekana', 'świeża lawenda, posiekana', 'świeża szałwia kilka listków', 'gałązki świeżego tymianku do dekoracji', 'ogórek do dekoracji', 'gałązki świeżego rozmarynu do dekoracji', 'świeża bazylia do dekoracji ', 'śmietana 18% do dekoracji', 'sałata kilka listków', 'rukola do dekoracji', 'rzeżucha do dekoracji', 'kiełki do dekoracji', 'świeża bazylia kilka listków', 'warzywa do dekoracji', 'śmietana do dekoracji', 'świeży rozmaryn do dekoracji ', 'pestki dyni do dekoracji', 'kiełki lucerny lub słonecznika do dekoracji', 'cukrowe perełki do dekoracji', 'jagody do dekoracji', 'świeża mięta posiekana', 'świeży majeranek do dekoracji', 'papryka do dekoracji', 'listki bazylii do dekoracji', 'natka do dekoracji', 'listki cykorii do dekoracji', 'pomidor (do dekoracji)', 'świeża kolendra posiekana', 'szczypiorek do dekoracji', 'gałązki koperku do dekoracji', 'pomidor do dekoracji', 'świeża mięta kilka listków', 'świeża szałwia listki', 'kiełki słonecznika do dekoracji', 'świeża szałwia do dekoracji', 'świeży koperek do dekoracji'}
#
# Cluster 37:
# (19 produktów): {'jogurt naturalny gęsty', 'gęsty jogurt grecki', 'jogurt naturalny', 'mały jogurt naturalny', 'jogurt naturalny typu greckiego', 'gesty jogurt naturalny', 'jogurtu naturalnego', 'jogurt naturalny bez cukru', 'jogurt naturalny 2%', 'gęsty jogurt naturalny', 'gęsty jogurt typu greckiego', 'jogurt naturalny grecki', 'jogurt naturalny mały ', 'jogurt gęsty typu greckiego ', 'jogurt naturalny 0%', 'gęsty jogurt typu bałkańskiego', 'jogurt typu greckiego', 'jogurt naturalny (mały)', '80 g jogurtu naturalnego'}
#
# Cluster 38:
# (28 produktów): {'sałata karbowana  listki', 'sałata karbowana ciemna, liście', 'sałata rzymska główka', 'sałata karbowana jasna', 'sałata lodowa, liście', 'sałata, liście', 'mini sałata rzymska', 'sałata lodowa kilka liści', 'sałata zielona liście ', 'sałata rzymska, liście ', 'sałata karbowana', 'sałata lodowa listki', 'sałata lodowa liście', 'sałata karbowana zielona', 'sałata rzymska mini', 'sałata karbowana lub lodowa liście', 'sałata lodowa główka', 'sałata liście', 'sałata rzymska', 'sałata masłowa, liście ', 'sałata masłowa liście', 'sałata lodowa pół główki', 'sałata - liście', 'sałata karbowana, liście', 'sałata karbowana ciemna', 'sałata karbowana zielona, liście', 'sałata karbowana - kilka listków', 'sałata lodowa średnia'}
#
# Cluster 39:
# (7 produktów): {'cyrtyna', 'cytyna', 'Cytryna', 'cytryna', '1 cytryna', '2 cytryny', 'cytryny'}
#
# Cluster 40:
# (8 produktów): {'kiełbasa parówkowa ', 'kiełbasa podwędzana', 'kiełbasa suszona', 'kiełbasa wędzona', 'kiełbasa paprykowa', 'kiełbasa zwyczajna', 'kiełbasa surowa ', 'kiełbasa jałowcowa'}
#
# Cluster 41:
# (3 produktów): {'ser zółty', 'ser żóty', 'ser żółty'}
#
# Cluster 42:
# (8 produktów): {'króliki świeże ', 'maliny świeże ', 'kurki świeże ', 'ogórki świeże ', 'borowiki świeże ', 'koperek świeży', 'ogórek świeży', 'raki świeże '}
#
# Cluster 43:
# (3 produktów): {'Majonez', ' majonezu', 'majonez'}
#
# Cluster 44:
# (4 produktów): {' keczupu', 'Ketchup ', 'ketchup', 'keczup'}
#
# Cluster 45:
# (15 produktów): {'makaron parpadelle', 'makaron ryżowy Vermicelli', 'Makaron Tagiatele', 'suchy makaron tagliatelle', 'makaron ryżowy Wernicchelli ', 'makaron ryżowy cienki vermicelli', 'makaron tagliatelle', 'makaron ryżowy cienki typu vermicelli', 'makaron farfalle', 'makaron Pappardelle', 'makaron np. tagliatelle', 'dwukolorowy makaron tagliatelle', 'makaron typu tagliatelle', 'makaron ryżowy tagliatelle ', 'makaron Tagiatelle '}
#
# Cluster 46:
# (3 produktów): {'pieczarki', 'pieczarek', 'pieczarka '}
#
# Cluster 47:
# (2 produktów): {'musztarda', 'musztada'}
#
# Cluster 48:
# (3 produktów): {'olej sezamowy', 'olej rzepakowy', 'olej rzepakowy '}
#
# Cluster 49:
# (3 produktów): {'zółty ser ', 'żółty ser', 'żółty  ser'}
#
# Cluster 50:
# (3 produktów): {'cukinie', 'cukina', 'cukinia'}
#
# Cluster 51:
# (2 produktów): {'sera feta', 'ser feta'}
#
# Cluster 52:
# (87 produktów): {'kilka gałązek świeżej bazylii', 'kilka gałązek świeżego koperku', 'gałązka świeżej bazylii', 'kilka listków świeżej bazylii lub koperku', 'pęczek świeżej mięty', '3 łyżeczki posiekanego koperku', 'pół pęczka posiekanej natki', 'kilka gałązek rozmarynu', 'pęczek posiekanego koperku', 'kilka liści jarmużu', 'garść świeżej kolendry', 'gałązka świeżej szałwii', 'gałązki świeżego majeranku', 'garść świeżej mięty', 'garść posiekanej natki', 'kilka listków świeżej bazylii', 'garść świeżego tymianku', '2 łyżki posiekanej mięty', 'gałązka świeżego tymianku', '2 łyżki posiekanego koperku', 'gałązka świeżego koperku', 'pęczek posiekanej kolendry', 'gałązki świeżego tymianku', 'kilka gałązek świeżej kolendry', 'kilka gałązek koperku', 'kilka listków świeżej szałwi', 'gałązka świeżego estragonu', '5 łyżek posiekanego koperku', 'garść posiekanej kolendry', 'pęczek świeżej posiekanej kolendry', 'garść posiekanej świeżej kolendry', '1 łyżka posiekanych kaparów', 'pęczek posiekanej natki', 'kilka liści bazylii', 'liście świeżej mięty', 'listki świeżej mięty', 'gałązka świeżego oregano', 'mała gałązka świeżego rozmarynu', 'liście świeżej szałwii', 'kilka listków sałaty', 'garść posiekanej bazylii', 'pęczek świeżego koperku', 'natka świeżej kolendry', 'liście świeżej bazylii', 'listki świeżego tymianku', 'liście świeżego tymianku', 'kilka gałązek świeżego rozmarynu', 'pęczek posiekanej dymki', 'gałązka świeżej mięty', 'mały pęczek posiekanej natki', 'gałązka świeżego rozmarynu', '2 łyżki posiekanej bazylii', 'gałązki świeżego rozmarynu', 'kilka gałązek świeżego majeranku', '10 listków bazylii', 'kilka gałązek świeżej mięty', 'listek świeżej bazylii', '1 pęczek posiekanej bazylii', 'posiekana gałązka rozmarynu', 'kilka gałązek tymianku', 'kilka listków świeżej kolendry', '2 łyżki posiekanych kaparów', 'kilka liści rukoli', 'listki świeżej szałwii', 'gałązka świeżego majeranku', 'gałązki świeżej szałwi', 'gałązki świeżego koperku', 'świeże listki bazylii', 'pęczek drobno posiekanego koperku', 'kilka gałązek oregano ', '4 łyżki posiekanej kolendry', 'kilka liści sałaty', 'garść liści kolendry', '1/2 pęczka posiekanego szczypiorku', 'świeże liście bazylii', 'pęczek świeżej bazylii', 'kilka listków świeżej szałwii', 'kilka listków bazylii', '1 pęczek posiekanej kolendry', 'kilka listków jarmużu', 'pęczek posiekanego szczypiorku', 'garść świeżej bazylii', 'garść świeżego szpinaku', 'listki świeżej bazylii', '1 łyżka posiekanej bazylii', 'kilka gałązek świeżego tymianku', 'pęczek świeżej kolendry'}
#
# Cluster 53:
# (2 produktów): {'kapary', 'kalmary'}
#
# Cluster 54:
# (13 produktów): {'czosnek - 3 ząbki', 'czosnek w ząbkach', 'czosnek - 2 ząbki', 'czosnek, ząbek', 'czosnek - 1 ząbek', 'czosnek ząbek', 'czosnek ząbki  ', 'czosnek-ząbki', 'Czosnek 2 ząbki ', 'Czosnek 3 ząbki', 'czosnek - ząbek', 'czosnek -  ząbki', 'czosnek - 4 ząbki'}
#
# Cluster 55:
# (2 produktów): {'kajzerka', 'kajzerki'}
#
# Cluster 56:
# (2 produktów): {'śledzie à la matjas w oleju', 'śledzie a’la matias w oleju'}
#
# Cluster 57:
# (3 produktów): {'jabłko', 'jablka', 'jabłka'}
#
# Cluster 58:
# (16 produktów): {'kukurydza w kolbie', 'kukurydza puszka', 'kukurydza kolby', 'minikukurydze w kolbach', 'słodka kukurydza z puszki', 'kukurydza mała puszka', 'kukurydza z groszkiem', 'kukurydza w puszce (mała)', 'kukurydza w kolbach ', 'kukurydza z puszki', 'kukurydza, puszka', 'kukurydza w puszce', '150 g kukurydzy z puszki', 'Kukurydza w puszcze', 'kukurydza  z puszki', 'kukurydza kolba'}
#
# Cluster 59:
# (4 produktów): {'musztarda stołowa ', 'musztarda Dijon', "musztarda d'jon", 'musztarda miodowa'}
#
# Cluster 60:
# (3 produktów): {'żółtko', 'żółtka', 'zółtko'}
#
# Cluster 61:
# (34 produktów): {'kurczak wędzony', 'buraki czerwone duże', 'oscypek wędzony', 'pieprz świeżo mielony', 'boczek wędzony', 'pieprz czarny świeżo mielony', 'boczek surowy', 'kurczak wędzony udko', 'pieprz naturalny, mielony', 'kurczak pieczony', 'burak czerwony', 'buraki upieczone', 'pieprz mielony', 'pieprz czarny świeżo mielony do smaku', 'burak pieczony', 'pieprz czarny grubo mielony ', 'pieprz biały', 'pieprz czarny, mielony', 'ser czerwony', 'buraki czerwone ', 'pieprz czarny mielony', 'czarny pieprz świeżo zmielony', 'Pieprz czarny mielony Knorr', 'pieprz czerwony', 'schab pieczony', 'boczek parzony', 'czarny pieprz mielony', 'pieprz grubo mielony', 'pieprz czarny grubo tłuczony', 'schab wieprzowy', 'pieprz czarny', 'pieprz ziołowy', 'pieprz kolorowy', 'pieprz biały mielony'}
#
# Cluster 62:
# (4 produktów): {'Brokuł', 'Brokuły', 'brokuł', 'brokuły'}
#
# Cluster 63:
# (2 produktów): {'szczypior', 'szczypiorek'}
#
# Cluster 64:
# (2 produktów): {'mięso rosołowe', 'mięso wołowe'}
#
# Cluster 65:
# (2 produktów): {'tymianek suszony', 'majeranek suszony'}
#
# Cluster 66:
# (2 produktów): {'pieprz', 'Pieprz'}
#
# Cluster 67:
# (11 produktów): {'oliwa z oliwek do sałatki', 'oliwa z oliwek bazyliowa', 'oliwa z oliwek do smażenia', 'oliwa z oliwek do dresingu', 'oliwa z oliwek truflowa', 'oliwa z oliwek do smarowania', 'oliwa lub olej do smażenia', 'olej lub oliwa do smażenia', 'oliwa z oliwek do wysmarowania formy', 'oliwa z oliwek chilli', 'oliwa z oliwek z ziołami'}
#
# Cluster 68:
# (4 produktów): {'chrzan tarty w słoiczku', 'chrzan w słoiczku', 'chrzan ze słoika', 'chrzan w słoiku'}
#
# Cluster 69:
# (10 produktów): {'twarożek Philadelphia ', 'serek kremowy typu philadelphia', 'ser typu philadelphia', 'serek kremowy typu philadelphia light', 'ser kremowy typu philadelphia', 'serek typu Philadelphia', 'serek Philadelphia ', 'serek śmietankowy typu philadelphia', 'Serek philadelphia', 'ser Philadelphia'}
#
# Cluster 70:
# (4 produktów): {'śliwki', 'oliwa', 'oliwka', 'oliwki'}
#
# Cluster 71:
# (3 produktów): {'szynka babuni pokrojona w cienkie plastry', 'szynka babuni (pokrojona w plastry)', 'szalotka pokrojona w cienkie plastry'}
#
# Cluster 72:
# (2 produktów): {'oliwa ze słoiczka z suszonymi pomidorami', 'olej ze słoiczka z suszonymi pomidorami'}
#
# Cluster 73:
# (3 produktów): {'pory', 'por', 'pora'}
#
# Cluster 74:
# (2 produktów): {'koper', 'koperek'}
#
# Cluster 75:
# (12 produktów): {'chrzan ostry', 'ser parmezan drobno starty', 'ser parmezan starty', 'ser parmezan, starty', 'parmezan utarty', 'chrzan tarty ', 'ser parmezan tarty', 'parmezan, starty', 'parmezan starty', 'parmezan (starty)', 'parmezan tarty ', 'chrzan starty'}
#
# Cluster 76:
# (3 produktów): {'świeża słonina', 'świeża dynia', 'świeża bazylia'}
#
# Cluster 77:
# (2 produktów): {'tortilla', 'tortille '}
#
# Cluster 78:
# (2 produktów): {' olej z oliwek', 'oliwa z oliwek'}
#
# Cluster 79:
# (26 produktów): {'kapusta pekińska', 'kapusta mała', 'kapusta młoda', 'mała kapusta pekińska', 'Kapusta pekińska ', 'kapusta włoska główka', 'kapusta  pekińska ', 'kapusta biała główka', 'kapusta pekińska mała', 'kapusta mała biała', 'kapusta włoska liście', 'kapusta włoska duża', 'kapusta pekińska - górne liście', 'kapusta włoska', 'kapusta pekińska główka mała', 'kapusta pekińska liście', 'kapusta włoska mała główka', 'kapusta pekińska, liśćie', 'kapusta  pekińska liście', 'kapusta słodka ', 'kapusta włoska lub biała', 'kapusta pekińska lub sałata', 'Kapusta biała', 'kapusta włoska gotowana', 'kapusta biała', 'kapusta włoska mała '}
#
# Cluster 80:
# (2 produktów): {'Ryż długoziarnisty lub specjalny do paelli', 'ryż długoziarnisty lub do paelli'}
#
# Cluster 81:
# (3 produktów): {'limonka', 'limonki', 'limetka'}
#
# Cluster 82:
# (2 produktów): {'szampan', 'szafran'}
#
# Cluster 83:
# (11 produktów): {'parmezan lub żółty ser', 'ser gruyer lub inny twardy ser', 'starty parmezan (lub inny ostry ser)', 'starty ser cheddar lub inny żółty ser', 'parmezan lub inny żółty ser', 'ser parmezan lub inny twardy ser', 'parmezan lub inny tarty ser', 'parmezan lub inny twardy ser', 'starty parmezan lub inny ser o ostrym smaku', 'Parmezan (lub inny twardy ser)', 'starty parmezan lub inny żółty ser'}
#
# Cluster 84:
# (4 produktów): {'musztarda sarepska', 'musztarda gruboziarnista', 'musztarda ziarnista', 'musztarda francuska'}
#
# Cluster 85:
# (13 produktów): {'płaski makaron ryżowy', 'makaron tagliatelle lub papardelle', 'makaron wstążki, np. tagliatelle lub papardelle', 'makaron jajeczny lub spaghetti', 'chiński makaron jajeczny  200gr', 'tajski makaron ryżowy ', 'makaron linguini lub spaghetti', 'makaron tagliatelle lub spaghetti', 'chiński makaron jajeczny', 'cienki makaron ryżowy', 'chiński makaron jajeczny lub spaghetti', 'chiński makaron ', 'chiński makaron ryżowy'}
#
# Cluster 86:
# (21 produktów): {' mrożonka mieszanka warzyw do dań chińskich', 'mieszanka mrożonych warzyw', 'mieszanka chińska mrożona', 'mrożone warzywa mieszanka chińska ', 'mieszanka warzywna mrożona', 'mrożona mieszanka warzywna', 'chińska mieszanka mrożonych warzyw', 'mieszanka warzyw na patelnię', 'mieszanka suszonych kwiatów ', 'chińska mieszanka warzyw', 'chińska mieszanka warzywna', 'mieszanka suszonych warzyw', 'mrożona mieszanka warzywna chińska', 'opakowanie mrożonych warzyw', 'tajlandzka mieszanka warzyw', 'chińska mieszanka warzyw na patelnię', 'Mrożona chińska mieszanka warzyw', 'mrożona mieszanka chińska', 'dowolna mrożona mieszanka warzywna', 'mrożona orientalna mieszanka warzyw', 'mrożona mieszanka warzyw na patelnię'}
#
# Cluster 87:
# (12 produktów): {'cebule dymki ze szczypiorkiem', 'cebula dymka ze szczypiorkiem', 'dymka ze szczypiorem ', 'cebulka dymka lub szczypiorek', 'cebula dymka ze szczypiorem', 'cebula dymka bez szczypioru, posiekana', 'cebula dymka za szczypiorkiem', 'cebula dymka bez szczypioru', 'cebule dymki razem ze szczypiorem', 'dymki ze szczypiorkiem', 'dymka ze szczypiorkiem ', 'cebulka dymka ze szczypiorkiem'}
#
# Cluster 88:
# (2 produktów): {'cukier', 'Cukier'}
#
# Cluster 89:
# (2 produktów): {'ciemne piwo', 'ciemne pieczywo'}
#
# Cluster 90:
# (2 produktów): {'świeży szpinak (lub o połowę mniej mrożonego)', 'świeży szpinak (lub 400 gram mrożonego)'}
#
# Cluster 91:
# (3 produktów): {'suszone pomidory', 'suszony pomidor', 'krojone pomidory'}
#
# Cluster 92:
# (9 produktów): {'orzechy pinii ', 'Orzeszki Pinni', 'orzeszki piniii', 'orzechy piniowe', 'orzechy laskowe', 'orzeszki piniowe', 'orzechy pinowe', 'orzeszki pinii', 'orzechy pini'}
#
# Cluster 93:
# (2 produktów): {'filety śledziowe', 'płaty śledziowe'}
#
# Cluster 94:
# (25 produktów): {'grzyby świeże lub mrożone', 'prawdziwki świeże lub mrożone', 'bób (może być mrożony)', 'bób świeży lub mrożony', 'grzyby suszone lub mrożone', 'groszek zielony (świeży lub mrożony)', 'zielony groszek (świeży lub mrożony)', 'podgrzybki świeże lub mrożone', 'szpinak (może być mrożony)', 'kurki świeże albo mrożone ', 'maliny świeże lub mrożone', 'groszek cukrowy świeży lub mrożony', 'zielony groszek (świeży lub mrożony) 120gr', 'młody bób (świeży lub mrożony)', 'podgrzybki (świeże lub mrożone)', 'brokuły świeże lub mrożone', 'brokuł (może być mrożony)', 'szpinak (świeży lub mrożony)', 'szpinak świeży lub mrożony', 'groszek (świeży lub mrożony)', 'kurki świeże lub mrożone', 'kalafior świeży lub mrożony', 'kalafior (może być mrożony)', 'kalafior i brokuł (świeży lub mrożony)', 'zielony groszek (świeży lub mrożony) 130gr'}
#
# Cluster 95:
# (2 produktów): {'młoda kiszona kapusta', 'kiszona kapusta'}
#
# Cluster 96:
# (15 produktów): {'średniej wielkości kajzerka', 'średniej wielkości papryka czerwona', 'średniej wielkości ziemniaki', 'średniej wielkości cebula', 'średniej wielkości cebule', 'średniej wielkości zielony ogórek', 'średniej wielkości czerwona cebula', 'średniej wielkości bakłażan', 'średniej wielkości cukinia', 'średniej wielkości pomidor', 'średniej wielkości wędzona makrela', 'średniej wielkości pomidory', 'średniej wielkości marchewka', 'średniej wielkości marchewki', 'średniej wielkości ogórek'}
#
# Cluster 97:
# (2 produktów): {'masło', 'Masło'}
#
# Cluster 98:
# (2 produktów): {'kapusta:', 'kapusta'}
#
# Cluster 99:
# (3 produktów): {'ugotowany ryż', 'ugotowany bób', 'ugotowany groch'}
#
# Cluster 100:
# (3 produktów): {'płatki kukurydziane', 'chrupki kukurydziane', 'płatki kukurydziane miodowe'}
#
# Cluster 101:
# (2 produktów): {'ryż', 'ryżu'}
#
# Cluster 102:
# (13 produktów): {'400 g tuńczyka w sosie własnym', 'tuńczyk w sosie własnym lub oleju z puszki', 'tuńczyk z puszki w zalewie własnej', 'tuńczyk w sosie własnym puszka', 'tuńczyk z puszki w oleju', 'tuńczyk w sosie własnym', '1 puszka tuńczyka w sosie własnym', 'tuńczyk z puszki w zalewie', 'tuńczyk w sosie własnym, mała puszka', 'puszka tuńczyka w sosie własnym', '200 g tuńczyka w sosie własnym', 'tuńczyk w sosie własnym (puszka)', 'tuńczyk z puszki w sosie własnym'}
#
# Cluster 103:
# (11 produktów): {'ser pleśniowy typu brie', 'ser pleśniowy np. Lazur', 'ser pleśniowy typu camembert', 'ser pleśniowy camembert', 'ser pleśniowy z pieprzem', 'ser pleśniowy typu rokpol', 'ser pleśniowy Lazur', 'ser pleśniowy rokpol', 'ser pleśniowy blue', 'ser pleśniowy', 'ser pleśniowy typu blue'}
#
# Cluster 104:
# (7 produktów): {'tosty z ziarnami kromki', 'pieczywo razowe pełnoziarniste, kromki', 'pieczywo pełnoziarniste', 'pieczywo tostowe pełnoziarniste, kromki', 'pieczywo pełnoziarniste, kromki', 'chleb tostowy pełnoziarnisty, kromki', 'pieczywo z ziarnami, kromki'}
#
# Cluster 105:
# (5 produktów): {'śledzie matias', 'śledzie Matjas', 'śledzie matias, płaty', 'śledź matias ', 'śledzie matiasy'}
#
# Cluster 106:
# (8 produktów): {'młody groszek', 'mrożony zielony groszek', 'mielony groszek ', 'młody zielony groszek', 'świeży zielony groszek', 'mrożony groszek', 'suszony zielony groszek', 'zielony groszek'}
#
# Cluster 107:
# (30 produktów): {'zielona fasolka szparagowa mamut', 'fasolka szparagowa mrożona', 'fasolka szparagowa świeża lub mrożona', 'pokrojona i ugotowana fasola szparagowa ', 'zielona fasolka mrożona', 'fasolka szparagowa żółta', 'fasolka szparagowa', 'mrożona fasolka szparagowa', 'zielona fasolka szparagowa', 'zielona fasolka szparagowa (ugotowana, pokrojona)', 'żółta fasolka szparagowa', 'żółta fasolka szparagowa w puszce', 'zielona fasolka szparagowa (świeża lub mrożona)', 'zielona fasolka szparagowa mrożona', 'fasola szparagowa', 'fasolka zielona mrożona', 'zielona fasolka szparagowa w puszce lub ugotowana', 'fasolka szparagowa zielona', 'fasolka szparagowa zielona (może być mrożona)', 'mrożona zielona fasola szparagowa ', 'fasolka szparagowa, zielona (świeża lub mrożona)', 'mrożona fasola szparagowa ', 'zielona fasolka szparagowa świeża', 'fasola szparagowa zielona', 'żółta fasolka szparagowa świeża lub mrożona', 'fasolka szparagowa oczyszczona', 'fasolka szparagowa w zalewie', 'fasola szparagowa (świeża lub mrożona)', 'fasola szparagowa (może być mrożona)', 'zielona fasolka  szparagowa  z puszki '}
#
# Cluster 108:
# (6 produktów): {'pół główki sałaty lodowej', 'liście sałaty lodowej', 'główka sałaty lodowej', 'listki sałaty lodowej', 'liść sałaty lodowej', 'liście sałaty masłowej '}
#
# Cluster 109:
# (16 produktów): {'golonka jagnięca bez kości', 'udziec wołowy bez kości ', 'kotlety jagnięce z kostką', 'comber jagnięcy z kostką', 'kotlet schabowy z kością ', 'kotlety cielęce z kostką', 'kotlety schabowe z kostką', 'kotlety ze schabu grube bez kości', 'udziec z indyka bez kości', 'udziec jagnięcy bez kości', 'kotlety jagnięce z kością', 'udziec barani bez kości ', 'udziec z indyka, bez kości i skóry ', 'comber jagnięcy bez kości', 'comber jagnięcy z kostkami', 'kotlety schabowe bez kości'}
#
# Cluster 110:
# (7 produktów): {'bułka namoczona w mleku ', 'kajzerka namoczona w wodzie', 'bułka namoczona w wodzie ', 'bułka pszenna namoczona w mleku', 'kajzerki namoczone w mleku ', 'kajzerka namoczona w mleku ', 'bułki namoczone w mleku '}
#
# Cluster 111:
# (2 produktów): {'czarna oliwka', 'czarne oliwki'}
#
# Cluster 112:
# (8 produktów): {'pieczywo tostowe pszenne', 'pieczywo chrupkie, kromki', 'pieczywo bezlaktozowe, kromki', 'pieczywo razowe, kromki', 'pieczywo pszenne, kromka', 'pieczywo tostowe, kromki', 'pieczywo razowe, kromka', 'pieczywo tostowe kromki'}
#
# Cluster 113:
# (2 produktów): {'Soda oczyszczona', 'soda oczyszczona'}
#
# Cluster 114:
# (2 produktów): {'Cynamon', 'cynamon'}
#
# Cluster 115:
# (2 produktów): {'cukier puder', 'Cukier puder'}
#
# Cluster 116:
# (7 produktów): {'nasiona słonecznika', 'pestki słonecznika', 'ziarno słonecznika', 'łuskane ziarna słonecznika', 'łuskane nasiona słonecznika', 'ziarna słonecznika', 'kiełki słonecznika'}
#
# Cluster 117:
# (2 produktów): {'serek ricotta', 'ser ricotta'}
#
# Cluster 118:
# (4 produktów): {'pikantny sos pomidorowy', 'sok pomidorowy', 'sos pomidorowy', 'ostry sos pomidorowy'}
#
# Cluster 119:
# (4 produktów): {'galaretka', 'kalarepa', 'kalarepy', 'kalarepka'}
#
# Cluster 120:
# (4 produktów): {'garść bazylii', 'pęczek bazylii', 'listek bazylii', 'liść bazylii'}
#
# Cluster 121:
# (9 produktów): {'świeża lub mrożona żurawina', 'Świeże lub mrożone maślaki', 'świeży lub mrożony koperek', 'Świeże lub mrożone kurki', 'Świeże lub mrożone prawdziwki', 'świeży lub mrożony szpinak', 'świeży lub mrożony bób', 'świeże lub mrożone maliny ', 'świeże lub mrożone brokuły'}
#
# Cluster 122:
# (2 produktów): {'muszle makaronowe ', 'duże muszle makaronowe'}
#
# Cluster 123:
# (3 produktów): {'pomidory pelati', 'pomidory pellati', 'pomidory pelatti'}
#
# Cluster 124:
# (3 produktów): {'wołowina zadnia', 'wołowina zrazowa ', 'wołowina gulaszowa'}
#
# Cluster 125:
# (5 produktów): {'ciasto francuskie, płat', 'gotowe ciasto kruche', 'mrożone ciasto francuskie', 'ciasto francuskie', 'gotowe ciasto francuskie'}
#
# Cluster 126:
# (6 produktów): {'parowki', 'borówki', 'parówka', 'karkówka', 'parówki', 'borowiki'}
#
# Cluster 127:
# (5 produktów): {'serek topiony kremowy', 'ser topiony śmietankowy', 'serki topione śmietankowe', 'serek kremowy śmietankowy', 'serek topiony śmietankowy'}
#
# Cluster 128:
# (2 produktów): {'śledź w oleju', 'śledzie w oleju'}
#
# Cluster 129:
# (2 produktów): {'kość wędzona', 'kości wędzone'}
#
# Cluster 130:
# (2 produktów): {'kiełbasa', 'kiełbaski'}
#
# Cluster 131:
# (9 produktów): {'młode cebulki szalotki ', 'cebulki szalotki', 'cebula szalotka, mała', 'małe cebulki szalotki', 'cebule szalotki', 'mała cebula szalotka', 'podłużna cebula szalotka', 'cebula szalotka', 'cebulka szalotka'}
#
# Cluster 132:
# (6 produktów): {'filety śledziowe np. matias', 'płaty śledziowe typu matias', 'płat śledzia a la matias', 'filety śledziowe w oleju', 'filety śledziowe matiasy', 'filety śledziowe solone'}
#
# Cluster 133:
# (2 produktów): {'grzanki:', 'grzanki'}
#
# Cluster 134:
# (3 produktów): {'płatki migdałów', 'płatki migdalów', 'płatki migdałowe '}
#
# Cluster 135:
# (2 produktów): {'woda-wrzątek', 'woda- wrzątek'}
#
# Cluster 136:
# (7 produktów): {'młoda kapusta', 'mała główka sałaty', 'duża główka kapusty', 'włoska kapusta', 'główka sałaty', 'główka kapusty', 'mała główka kapusty'}
#
# Cluster 137:
# (3 produktów): {'korzeń pietruszki', 'duży korzeń pietruszki', 'gruby korzeń pietruszki'}
#
# Cluster 138:
# (3 produktów): {'pomidory cherry ', 'pomidorki cherry żółte ', 'pomidorki cherry '}
#
# Cluster 139:
# (14 produktów): {'żółtka z jaj ', 'białko z jaja ', 'białko jajka', 'białka jajka', 'białka z jaj', 'żółtko jajka', 'białka jajek', 'żółtka jaj', 'białko z jajka ', 'żółtka jajek', 'białko z jajek', 'zółtko z jajek', 'żółtko jaja', 'białko z jaja'}
#
# Cluster 140:
# (10 produktów): {'pikantne kiełbaski (chorizo)', 'ostra kiełbaska, np. chorizo', 'kiełbasa chorizo', 'kiełbaska chorizo ', 'ostra kiełbasa chorizo', 'małe kiełbaski chorizo ', 'kiełbasa typu chorizo', 'surowe kiełbaski chorizo ', 'pętko kiełbasy chorizo', 'kiełbaski chorizo '}
#
# Cluster 141:
# (4 produktów): {'nasiona kolendry', 'natka kolendry', 'listki kolendry', 'ziarna kolendry'}
#
# Cluster 142:
# (3 produktów): {'chipsy nachos', 'chipsy taco', 'chipsy tacos'}
#
# Cluster 143:
# (5 produktów): {'papryka zółta', 'papryka mała ', 'papryka żółta', 'papryka biała', 'papryka  żółta'}
#
# Cluster 144:
# (2 produktów): {'placki tortilla z mąki kukurydzianej', 'tortilla z mąki kukurydzianej '}
#
# Cluster 145:
# (3 produktów): {'rzodkiewki', 'rzodkiewka', 'rzodkiew'}
#
# Cluster 146:
# (4 produktów): {'wywar warzywny', 'wywar z warzyw ', 'wywar z jarzyn ', 'wywar rybny'}
#
# Cluster 147:
# (13 produktów): {'polędwiczka wieprzowa - 150 gram', 'polędwiczka wieprzowa', 'polędwica wołowa', 'polędwiczka wieprzowa (mała)', 'polędwiczki wieprzowe', 'polędwiczki drobiowe', 'gruba polędwiczka wieprzowa', 'polędwica łososiowa', 'polędwica sopocka ', 'polędwica wieprzowa surowa', 'polędwiczka wieprzowa 200gr', 'dwie polędwiczki wieprzowe', 'polędwica wieprzowa'}
#
# Cluster 148:
# (7 produktów): {'gałązki selera naciowego', '2 gałązki selera naciowego', 'łodyżki selera naciowego', 'łodyga selera naciowego', 'gałązka selera naciowego', 'kawałek selera naciowego', 'łodygi selera naciowego'}
#
# Cluster 149:
# (2 produktów): {'jogurt ', 'jourt'}
#
# Cluster 150:
# (15 produktów): {'świeże pomidory', 'duże pomidory', 'mały pomidor', 'duże dojrzałe pomidory', 'świeży pomidor', 'dojrzałe pomidory', 'dojrzały pomidor', 'żółty pomidor', 'duże dojrzałe awokado ', 'dojrzałe awokado', 'duży pomidor ', 'dobrze dojrzałe pomidory', 'obrane pomidory ', 'twardy pomidor', 'małe pomidory'}
#
# Cluster 151:
# (2 produktów): {'żurawina mrożona', 'żurawina suszona'}
#
# Cluster 152:
# (9 produktów): {'placki na tortille', 'paczka tortilli', 'gotowe placki tortilla ', 'placki tortilli', 'placki tortille', 'duże placki tortilla', 'małe placki tortilla ', 'placki tortilla', 'placek tortilli'}
#
# Cluster 153:
# (4 produktów): {'zielony groszek w strąkach ', 'zielony groszek w puszce', 'chiński groszek w strąkach ', 'zielony groszek z puszki'}
#
# Cluster 154:
# (2 produktów): {'kapusta kiszona', 'kapusta kwaszona'}
#
# Cluster 155:
# (2 produktów): {'suche drożdże', 'suszone drożdże'}
#
# Cluster 156:
# (2 produktów): {'kotlety schabowe', 'kotlet schabowy'}
#
# Cluster 157:
# (7 produktów): {'Sos sałatkowy Czosnkowo-ziołowy Knorr', 'Sos sałatkowy Czosnkowy Knorr', 'Sos sałatkowy Francuski Knorr', 'Sos sałatkowy Koperkowo-ziołowy Knorr', 'Sos sałatkowy Paprykowo-ziołowy Knorr', 'Sos sałatkowy Do mizerii Knorr', 'Sos sałatkowy Włoski Knorr'}
#
# Cluster 158:
# (4 produktów): {'orzechy, np. nerkowce', 'orzechy nerkowca', 'orzech nerkowca', 'orzeszki nerkowca'}
#
# Cluster 159:
# (3 produktów): {'mandarynka', 'margaryna', 'mandarynki'}
#
# Cluster 160:
# (4 produktów): {'czerwona kapusta poszatkowana', 'biała kapusta posiekana ', 'biała kapusta poszatkowana', 'kapusta poszatkowana'}
#
# Cluster 161:
# (14 produktów): {'obrane krewetki', 'ugotowane krewetki', 'gotowane krewetki', 'duże mrożone krewetki', 'surowe krewetki', 'Suszone krewetki', 'mrożone krewetki', 'oczyszczone borowiki ', 'surowe oczyszczone krewetki', 'duże krewetki', 'surowe obrane krewetki ', 'duże obrane krewetki ', 'oczyszczone krewetki', 'obgotowane krewetki'}
#
# Cluster 162:
# (3 produktów): {'świeży imbir', 'świeży imbir 5 cm', 'świeży imbir 6 cm'}
#
# Cluster 163:
# (3 produktów): {'puszka napoju kokosowego', 'puszka mleka kokosowego', 'puszka mleczka kokosowego'}
#
# Cluster 164:
# (2 produktów): {'sos chilli', 'sos chili'}
#
# Cluster 165:
# (3 produktów): {'mała kapusta ', 'biała kapusta', 'świeża kapusta'}
#
# Cluster 166:
# (3 produktów): {'twardy ser owczy', 'twardy ser kozi', 'twardy ser feta'}
#
# Cluster 167:
# (12 produktów): {'kasza jęczmienna pęczak / wiejska', 'kasza jęczmienna perłowa średnia', 'kasza jęczmienna', 'kasza jęczmienna w woreczku', 'kasza jęczmienna (perłowa) ', 'kasza jęczmienna gruba', 'kasza jęczmienna (paczka)', 'kasza jęczmienna pęczak', 'sucha kasza jęczmienna pęczak', 'kasza jęczmienna pęczak (sucha)', 'kasza jęczmienna drobna ', 'kasza jęczmienna perłowa'}
#
# Cluster 168:
# (2 produktów): {'Por (mały)', 'por mały'}
#
# Cluster 169:
# (3 produktów): {'kasza gryczana', 'mąka gryczana', 'mąka gryczana '}
#
# Cluster 170:
# (11 produktów): {'suszone gruszki', 'suszone grzyby leśne', 'mrożone podgrzybki', 'suszone grzyby kapelusze', 'namoczone grzyby mun', 'suszone grzybki', 'suszone podgrzybki', 'suszone grzyby', 'suszone grzyby shitake', 'suszone grzyby mun', 'mieszane grzyby'}
#
# Cluster 171:
# (3 produktów): {'ryż, np. basmati', 'ryż np. basmati', 'ryż basmati'}
#
# Cluster 172:
# ...
#
# Cluster 809:
# (2 produktów): {'tymianek - kilka gałązek', 'rozmaryn - kilka gałązek'}
#
# Cluster 810:
# (3 produktów): {'jogurt naturalny 0% tłuszczu', 'jogurt naturalny niskotłuszczowy', 'jogurt naturalny 2% tłuszczu'}
#
# Cluster 811:
# (3 produktów): {'świeży łosoś filet ze skórą', 'świeży łosoś bez skóry', 'świeży dorsz, filet bez skóry'}
#
# Cluster 812:
# (2 produktów): {'suszone pomidory z kaparami w oliwie z oliwek', 'suszone pomidory z kaparami i czarnymi oliwkami '}
#
# Cluster 813:
# (2 produktów): {'ogórki gruntowe', 'ogórek gruntowy'}
#
# Cluster 814:
# (2 produktów): {'mąka pszenna tortowa', 'mąka pszenna / mąka tortowa'}
#
# Cluster 815:
# (2 produktów): {'twarożek kanapkowy Bieluch', 'serek kanapkowy Bieluch'}
#
# Cluster 816:
# (2 produktów): {'rozmaryn (świeży lub suszony)', 'tymianek (świeży lub suszony)'}
#
# Cluster 817:
# (2 produktów): {'mix sałat z roszponką', 'mix sałat z rukolą'}
#
# Cluster 818:
# (4 produktów): {'kalafior różyczki małe', 'kalafior różyczki ', 'kalafior (same różyczki)', 'kalafior różyczki  małe'}
#
# Cluster 819:
# (3 produktów): {'suszone liście Kafiru', 'suszone liście curry', 'suszony listek Kafiru'}
#
# Cluster 820:
# (2 produktów): {'zmielone otręby owsiane', 'mielone otręby pszenne'}
#
# Cluster 821:
# (5 produktów): {'oliwki zielone marynowane', 'oliwki zielone lub czarne', 'oliwki czarne drylowane ', 'oliwki zielone drylowane', 'oliwki czarne, drylowane'}
#
# Cluster 822:
# (2 produktów): {'suszona bazylia do smaku', 'świeża bazylia do smaku'}
#
# Cluster 823:
# (2 produktów): {'udziec wołowy, chudy', 'udziec wołowy surowy, chudy'}
#
# Cluster 824:
# (4 produktów): {'otręby pszenne, mielone', 'otręby pszenne mielone', 'otręby owsiane, mielone', 'otręby pszenne prażone '}
#
# Cluster 825:
# (4 produktów): {'1 listek laurowy', 'listki laurowe', 'liść laurowy', 'listek laurowy'}
#
# Cluster 826:
# (2 produktów): {'suszone oregano do smaku', 'suszony tymianek do smaku'}
#
# Cluster 827:
# (2 produktów): {'makaron gryczany świderki (suchy)', 'makaron gryczany, świderki (suchy)'}
#
# Cluster 828:
# (2 produktów): {'6 ziarenek pieprzu czarnego', 'kilka ziarenek pieprzu czerwonego'}
#
# Cluster 829:
# (2 produktów): {'dorsz filety', 'dorsz filet'}
#
# Cluster 830:
# (2 produktów): {'mielony kminek', 'mielony kumin'}
#
# Cluster 831:
# (2 produktów): {'mała grahamka', 'bułka grahamka'}
#
# Cluster 832:
# (2 produktów): {'kapusta kiszona czerwona', 'kapusta kiszona domowa'}
#
# Cluster 833:
# (3 produktów): {'ogórek zielony wężowy', 'ogórek zielony świeży', 'ogórek zielony gruntowy'}
#
# Cluster 834:
# (3 produktów): {'sos tajski', 'sos tatarski', 'sos tamari'}
#
# Cluster 835:
# (2 produktów): {'cytryna sok', 'cytryna 1/2'}
#
# Cluster 836:
# (2 produktów): {'jabłko antonówka', 'jabłka antonówki'}
#
# Cluster 837:
# (3 produktów): {'cebula - 2 szt.', 'cebula -  1 szt.', 'cebula - 1/2 szt.'}
#
# Cluster 838:
# (2 produktów): {'ośmiorniczki', 'ośmiornica '}
#
# Cluster 839:
# (3 produktów): {'przyprawa do dań kuchni meksykańskiej', 'przyprawa kuchni meksykańskiej ', 'przyprawa do kuchni chińskiej'}
#
# Cluster 840:
# (2 produktów): {'sprawiony sandacz', 'sprawiony leszcz'}
#
# Cluster 841:
# (3 produktów): {'Przyprawa Uniwersalna Delikat', 'Przyprawa Uniwersalna Delikat ', 'Przyprawa Uniwersalna  Delikat '}
#
# Cluster 842:
# (3 produktów): {'kurczak świeży ', 'boczek świeży ', 'Groszek świeży'}
#
# Cluster 843:
# (4 produktów): {'Czerstwy razowy chleb kromka', 'czerstwy żytni chleb kromki', 'czerstwy chlem kromki', 'czerstwy chleb kromki'}
#
# Cluster 844:
# (2 produktów): {'sardele', 'sardela'}
#
# Cluster 845:
# (3 produktów): {'ciasto na pizze ', 'ciasto na pizze:', 'ciasto do pizzy:'}
#
# Cluster 846:
# (2 produktów): {'mrożona sałatka meksykańska ', 'mrożonka meksykańska '}
#
# Cluster 847:
# (2 produktów): {'ser solan ', 'ser salami '}
#
# Cluster 848:
# (4 produktów): {'filety z ryby morskiej', 'filet z ryby morskiej', 'filety z ryb morskich', 'mięso z ryby morskiej'}
#
# Cluster 849:
# (2 produktów): {'gęsie udka', 'żabie udka'}
#
# Cluster 850:
# (2 produktów): {'ciasto wonton ', 'ciasto na won tony'}
#
# Cluster 851:
# (2 produktów): {'kotlety ', 'kotlety:'}
#
# Cluster 852:
# (2 produktów): {'puszka białej fasoli konserwowej', 'puszka czerwonej fasoli konserwowej'}
#
# Cluster 853:
# (2 produktów): {'wędzona surowa polędwica', 'wędzona polędwica'}
#
# Cluster 854:
# (2 produktów): {'marynowane śledzie ', 'marynowane śledzie w oleju'}
#
# Cluster 855:
# (2 produktów): {'panierka', 'panierka:'}
#
# Cluster 856:
# (2 produktów): {'chilli posiekane', 'chili posiekana '}
#
# Cluster 857:
# (2 produktów): {'śmietana w sprayu ', 'bita śmietana w sprayu'}
#
# Cluster 858:
# (4 produktów): {'suszony majeranek', 'suszony tymianek', 'suszony czosnek ', 'suszony tymianek '}
#
# Cluster 859:
# (2 produktów): {'sok z cytryny - z 1/2 szt.', 'sok z cytryny z 1/2 szt.'}
#
# Cluster 860:
# (4 produktów): {'koperek - 1 pęczek', 'koperek - 1 mały pęczek', 'Koperek pęczek', 'kperek pęczek'}
#
# Cluster 861:
# (3 produktów): {'Sos beszamel', 'sos beszamelowy', 'sos beszamelowy:'}
#
# Cluster 862:
# (2 produktów): {'masło czosnkowe:', 'masło czosnkowe'}
#
# Cluster 863:
# (3 produktów): {'ogórki małosolne', 'ogórek małosolny', 'ogórki małosłone'}
#
# Cluster 864:
# (4 produktów): {'grzyby marynowane pokrojone ', 'dynia marynowana w słoiku', 'grzyby marynowane w słoiku ', 'cebula marynowana w słoiku'}
#
# Cluster 865:
# (2 produktów): {'gulasz:', 'gulasz'}
#
# Cluster 866:
# (2 produktów): {'pieczarki posiekane ', 'pieczarki pokrojone '}
#
# Cluster 867:
# (2 produktów): {'ciasto składniki mokre:', 'ciasto składniki suche:'}
#
# Cluster 868:
# (2 produktów): {'masa:', 'masala:'}
#
# Cluster 869:
# (2 produktów): {'Puszka kukurydzy konserwowej', 'mini kolby kukurydzy konserwowej'}
#
# Cluster 870:
# (4 produktów): {'szparagi ze słoika ', 'kapary w słoiku', 'kapary ze słoika ', 'szparagi w słoiku'}
#
# Cluster 871:
# (2 produktów): {'długoziarnisty biały ryż', 'długoziarnisty ryż'}
#
# Cluster 872:
# (2 produktów): {'filet ze śledzia', 'filety ze śledzi'}
#
# Cluster 873:
# (2 produktów): {'jabłko kwaskowe', 'jabłko kwaskowate '}
#
# Cluster 874:
# (2 produktów): {'chrzan ze śmietaną', 'chrzan tarty ze śmietaną '}
#
# Cluster 875:
# (2 produktów): {'kuropatwy', 'kuropatwa '}
#
# Cluster 876:
# (2 produktów): {'serek twarogowy z ziołami', 'serek śmietankowy z ziołami'}
#
# Cluster 877:
# (2 produktów): {'homar', 'homary'}
#
# Cluster 878:
# (2 produktów): {'filet ze szczupaka ', 'filety ze szczupaka '}
#
# Cluster 879:
# (2 produktów): {'kandyzowana skórka pomarańczowa', 'kandyzowana skórka pomarańczy'}
#
# Cluster 880:
# (3 produktów): {'2 laski wanilii', '1 laska wanilii', 'laska wanilii'}
#
# Cluster 881:
# (2 produktów): {'placki ryżowe', 'płatki ryżowe'}
#
# Cluster 882:
# (4 produktów): {'suszone chilli anchos ', 'suszone chiles pasillas', 'suszone chiles anchos', 'suszone chiles guajillos '}
#
# Cluster 883:
# (2 produktów): {'czerwone porzeczki ', 'czerwonych porzeczek'}
#
# Cluster 884:
# (2 produktów): {'świeże strączki czerwonego chili ', 'utłuczone strączki czerwonego chili '}
#
# Cluster 885:
# (3 produktów): {'mielone suszone pomidory', 'mielone suszone grzyby', 'ugotowane suszone grzyby'}
#
# Cluster 886:
# (2 produktów): {'przyprawa warzywna', 'przyprawa korzenna '}
#
# Cluster 887:
# (2 produktów): {'mielone', 'melon'}
#
# Cluster 888:
# (2 produktów): {'móżdżek cielęcy', 'mostek cielęcy'}
#
# Cluster 889:
# (2 produktów): {'pasztet drobiowy', 'pasztet domowy '}
#
# Cluster 890:
# (2 produktów): {'średni bakłażan', 'średnie bakłażany '}
#
# Cluster 891:
# (3 produktów): {'jajka surowe ', 'jajko surowe ', 'jaja surowe '}
#
# Cluster 892:
# (2 produktów): {'pierścień z kalmara', 'pierścienie z kalmarów '}
#
# Cluster 893:
# (2 produktów): {'gotowane mięso z kraba', 'gotowane mięso z krabów '}
#
# Cluster 894:
# (2 produktów): {'pstrągi duże ', 'pstrąg duży '}
#
# Cluster 895:
# (2 produktów): {'czarne oliwki mały słoik', 'czarne oliwki słoik'}
#
# Cluster 896:
# (2 produktów): {'sok z grejpfruta', 'skórka z grejpfruta'}
#
# Cluster 897:
# (3 produktów): {'sos czosnkowy', 'sól czosnkowa', 'sos czosnkowy:'}
#
# Cluster 898:
# (2 produktów): {'pieczarki świeże', 'pieczarki świeże, duże'}
#
# Cluster 899:
# (2 produktów): {'przyprawa maggi w płynie', 'przyprawa do zup w płynie'}
#
# Cluster 900:
# (2 produktów): {'laski kiełbasy ', 'laska kiełbasy '}
#
# Cluster 901:
# (4 produktów): {'przyprawa bałkańska', 'przyprawa indyjska', 'przyprawa włoska', 'przyprawa chińska'}
#
# Cluster 902:
# (2 produktów): {'cebula ugotowana w wywarze ', 'seler  gotowany w wywarze '}
#
# Cluster 903:
# (2 produktów): {'nalewka wiśniowa', 'galaretka wiśniowa'}
#
# Cluster 904:
# (2 produktów): {'pokrojony seler naciowy ', 'posiekany seler naciowy'}
#
# Cluster 905:
# (2 produktów): {'Polewa', 'polewa'}
#
# Cluster 906:
# (3 produktów): {'czarne oliwki pokrojone ', 'oliwki pokrojone ', 'czarne oliwki pokrojone w krążki'}
#
# Cluster 907:
# (2 produktów): {'krewetki z zalewy', 'krewetki w zalewie '}
#
# Cluster 908:
# (2 produktów): {'pokrojona w ćwiartki cebula ', 'pokrojona w półkrążki cebula'}
#
# Cluster 909:
# (2 produktów): {'kanapki z serem:', 'kanapki z fetą:'}
#
# Cluster 910:
# (3 produktów): {'makaron spagetti porcja', 'makaron spagetti (porcja)', 'makaron spaghetti Lubella'}
#
# Cluster 911:
# (2 produktów): {'kartofle', 'kartofel'}
#
# Cluster 912:
# (2 produktów): {'korniszony słoik', 'korniszony słoik mały'}
#
# Cluster 913:
# (2 produktów): {'ser w kostce', 'feta w kostce'}
#
# Cluster 914:
# (2 produktów): {'sałata lollo roso ciemna liście', 'sałata lollo roso biała liście'}
#
# Cluster 915:
# (9 produktów): {'Przyprawa w Mini kostkach Czosnek - kostka', 'Przyprawa w mini kostkach Smażona Cebula Knorr', 'Przyprawa w mini kostkach Majeranek Knorr', 'Przyprawa w mini kostkach Czosnek Knorr', 'Przyprawa w Mini kostkach Pietruszka - kostka', 'Przyprawa w mini kostkach Bazylia Knorr ', ',, Przyprawa w mini kostkach majeranek "', 'Przyprawa  w mini kostkach smażona cebulka " ', 'Przyprawa w Mini kostkach Smażona cebula - kostka'}
#
# Cluster 916:
# (3 produktów): {'przypraw z zupek chińskich ', 'makaron z zupek chińskich', 'makaron z zupek chinskich'}
#
# Cluster 917:
# (2 produktów): {'makaron w kształcie ryżu', 'makaron w kształcie kokardek'}
#
# Cluster 918:
# (2 produktów): {'przednia golonka', 'średnie golonki'}
#
# Cluster 919:
# (3 produktów): {'kalafior biały ', 'kalafior mały', 'kalafior młody'}
#
# Cluster 920:
# (2 produktów): {'konfitura malinowa', 'konfitura morelowa'}
#
# Cluster 921:
# (2 produktów): {'serek topiony bez dodatków', 'serek topiony kremowy bez dodatków'}
#
# Cluster 922:
# (2 produktów): {'ser Dziugas albo inny typu parmezan', 'ser Dziugas albo inny typu parmezan, w płatkach'}
#
# Cluster 923:
# (2 produktów): {'sól (najlepiej morska), świeżo mielony pieprz', 'sól morska, świeżo zmielony pieprz'}
#
# Cluster 924:
# (3 produktów): {'schab bez kości plastry', 'schab bez kości 4 kotlety', 'schab bez kości - plastry'}
#
# Cluster 925:
# (2 produktów): {'słonina w kawałku', 'szynka w kawałku'}
#
# Cluster 926:
# (3 produktów): {'1 mała czerwona papryczka chili oczyszczona z pestek i pokrojona w krążki', '1 zielona papryka oczyszczona z pestek i pokrojona na cząstki', '1 czerwona papryka oczyszczona z pestek i pokrojona na cząstki'}
#
# Cluster 927:
# (2 produktów): {'3 liście laurowe', '2 liście laurowe'}
#
# Cluster 928:
# (2 produktów): {'bułka tarta z mąką', 'bułka tarta do masy '}
#
# Cluster 929:
# (3 produktów): {'50 g kurek', '120 g kurek', '300 g kurek'}
#
# Cluster 930:
# (3 produktów): {'500 ml wody ', '200 ml wody ', '500 ml wody'}
#
# Cluster 931:
# (2 produktów): {'100 ml octu', '100 ml oleju'}
#
# Cluster 932:
# (2 produktów): {'kiełbasa toruńska lub inna ', 'kiełbasa (śląska lub inna)'}
#
# Cluster 933:
# (2 produktów): {'mały pęczek szparagów', 'pół pęczka szparagów'}
#
# Cluster 934:
# (2 produktów): {'pasztet delikatesowy z żurawiną', 'pasztet delikatesowy z pieprzem '}
#
# Cluster 935:
# (2 produktów): {'pierś z kurczaka - 300 gram', 'pierś z kurczaka - 200 gram'}
#
# Cluster 936:
# (2 produktów): {'rodzynki jasne', 'rodzynki ciemne'}
#
# Cluster 937:
# (3 produktów): {'4 roztrzepane jajka', 'roztrzepane jajo', '1 roztrzepane jajko'}
#
# Cluster 938:
# (3 produktów): {'jajko - 2 szt.', 'jajko - 1 szt.', 'jajka - 2 sztuki'}
#
# Cluster 939:
# (2 produktów): {'cały wypatroszony pstrąg', 'całe wypatroszone pstrągi'}
#
# Cluster 940:
# (2 produktów): {'ziemniaki - 4 szt.', 'ziemniaki 2szt '}
#
# Cluster 941:
# (2 produktów): {'pomidor podłużny żółty', 'pomidor podłużny czerwony'}
#
# Cluster 942:
# (2 produktów): {'zupka chińska ostra', 'zupka chińska łagodna'}
#
# Cluster 943:
# (2 produktów): {'200 g masła', '20 g masła'}
#
# Cluster 944:
# (2 produktów): {'50 g brukselki', '50 g gruszki'}
#
# Cluster 945:
# (4 produktów): {'50 ml białego wytrawnego wina', '2/3 szklanki białego wytrawnego wina', '60 ml białego wytrawnego wina', '1/2 szklanki białego wytrawnego wina'}
#
# Cluster 946:
# (8 produktów): {'200 ml śmietany', '100 ml śmietany 36', '100 ml śmietanki 30%', '300 ml śmietany 36%', '200 ml śmietany 36', '250 ml śmietanki 36%', '200 ml śmietanki 36 %', '100 ml śmietany'}
#
# Cluster 947:
# (9 produktów): {'1 łyżka oliwy', '2 łyżki oliwy', '6 łyżek oliwy', '3 łyżki oliwy', '5 łyżek oliwy', '7 łyżek oliwy', '8 łyżek oliwy', '3 łyżki oleju', '3 +3 łyżki oliwy'}
#
# Cluster 948:
# (2 produktów): {'10 łyżek przesianej mąki', '200 g przesianej mąki'}
#
# Cluster 949:
# (2 produktów): {'1 łyżka brązowego cukru trzcinowego', '1 łyżka cukru trzcinowego'}
#
# Cluster 950:
# (3 produktów): {'½ szklanki śmietany (36', '½ szklanki śmietany 36', '2 szklanki śmietany 36'}
#
# Cluster 951:
# (2 produktów): {'100 g stopionego masła', '50 g stopionego masła'}
#
# Cluster 952:
# (3 produktów): {'6 łyżek cukru', '4 łyżki cukru', '2 łyżki cukru'}
#
# Cluster 953:
# (2 produktów): {'1 łyżka masła', '1 łyżeczka masła'}
#
# Cluster 954:
# (6 produktów): {'1 łyżka oliwy extra virgine', '3/4 szklanki oliwy extra virgine', '2 łyżki oliwy extra virgine', '4 łyżki oliwy extra virgine', '9 łyżek oliwy extra virgine', '6 łyżek oliwy extra virgine'}
#
# Cluster 955:
# (2 produktów): {'150 ml mleka', '600 ml mleka'}
#
# Cluster 956:
# (5 produktów): {'4 łyżki sosu rybnego', '1 łyżka sosu rybnego', '2 łyżki sosu rybnego', '2 łyżki octu winnego', '1 łyżka sosu sojowego'}
#
# Cluster 957:
# (3 produktów): {'1 łyżka ostrej musztardy', '5 łyżek ostrej musztardy', '1 łyżka łagodnej musztardy'}
#
# Cluster 958:
# (2 produktów): {'100 ml gęstej śmietany', '200 g gęstej śmietany 36%'}
#
# Cluster 959:
# (2 produktów): {'2 łyżki mąki', '1 łyżka mąki'}
#
# Cluster 960:
# (2 produktów): {'masło lub margaryna do formy', 'masło lub margaryna do smażenia'}
#
# Cluster 961:
# (2 produktów): {'4 łyżki octu balsamicznego', '1 łyżka octu balsamicznego'}
#
# Cluster 962:
# (2 produktów): {'1 łyżka brązowego cukru', '2 łyżki brązowego cukru'}
#
# Cluster 963:
# (2 produktów): {'2 łyżki oleju arachidowego', '1 łyżka oleju arachidowego'}
#
# Cluster 964:
# (2 produktów): {'2 posiekane dymki (tylko białe części)', '5 posiekanych cebulek dymek (tylko białe części)'}
#
# Cluster 965:
# (2 produktów): {'2 polędwiczki wieprzowe pokrojone w plasterki o grubości 5 mm', '600 g polędwiczek wieprzowych pokrojonych w plasterki o grubości 1 cm'}
#
# Cluster 966:
# (4 produktów): {'1 minikosteczka przyprawowa Czosnek Knorr', '1 mini kostka przyprawowa Czosnek Knorr', '1 minikostka przyprawowa Czosnek Knorr', '1 mini kostka przyprawowa Pieprz kolorowy Knorr'}
#
# Cluster 967:
# (2 produktów): {'150 g wędzonego boczku (bez skóry i kostek) pokrojonego w paseczki', '200 g wędzonego boczku (bez skóry i kostek) pokrojonego w grubą kostkę lub w słupki'}
#
# Cluster 968:
# (2 produktów): {'1 kostka bulionu drobiowego Knorr', '2 kostki bulionu warzywnego Knorr'}
#
# Cluster 969:
# (3 produktów): {'2 łyżki posiekanych czarnych oliwek', '20 g posiekanych czarnych oliwek', '10 posiekanych czarnych oliwek'}
#
# Cluster 970:
# (2 produktów): {'łyżeczka startego imbiru', '2 łyżeczki startego imbiru'}
#
# Cluster 971:
# (2 produktów): {'6 posiekanych anchois', '8 posiekanych anchois'}
#
# Cluster 972:
# (2 produktów): {'100 g posiekanych suszonych pomidorów', '60 g posiekanych suszonych pomidorów'}
#
# Cluster 973:
# (2 produktów): {'3 oczyszczone filety z pstrąga', '4 oczyszczone świeże pstrągi'}
#
# Cluster 974:
# (2 produktów): {'300 g filetów z soli', '300 g filetów z łososia'}
#
# Cluster 975:
# (2 produktów): {'1 żółta papryka oczyszczona z pestek i białych błonek i pokrojona w kostkę', '2 czerwone papryki oczyszczone z pestek i białych błonek i pokrojone w kostkę'}
