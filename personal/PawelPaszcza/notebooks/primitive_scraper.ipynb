# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# req_url = 'https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?symbol=posglos&NrKadencji=8'
req_url = 'https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp'
req_params = dict(symbol='posglos', NrKadencji=8)
source_url = 'https://www.sejm.gov.pl/Sejm8.nsf/'

# %%
try:
    r = requests.get(req_url, req_params)
except Exception as e:
    print(e)
else:
    print(f"Status code:  {r.status_code}")
    print(f"Content type: {r.headers['content-type']}")
    # print(r.text)
    html = r.text
# Out:
# Status code:  200
# Content type: text/html;charset=utf-8

# %%
#soup = BeautifulSoup(html, 'html.parser')
soup = BeautifulSoup(html, 'lxml')

# %%
df = pd.DataFrame()

# %%
l = []

# %%
for a in soup.table.find_all('a'):
    l.append([a.text,source_url+a.get('href')])
    #print(a.text,'\t',a.get('href'))

# %%
df1 = pd.DataFrame(l,columns=['Data pos. Sejmu','Link'])

# %%
voting_df = pd.read_html('https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?symbol=posglos&NrKadencji=8')[0]

# %%
voting_df.fillna(method='ffill', inplace=True)

# %%
voting_df = voting_df.iloc[:,:3]

# %%
voting_df.iloc[:,1] = df1.iloc[:,0]

# %%
voting_df['Link'] = df1.iloc[:,1]

# %% [markdown]
# voting_df

# %%
def date_parser(date_str):
    
    month_dict = {'stycznia' : 1,
                  'lutego' : 2,
                  'marca' : 3,
                  'kwietnia' : 4,
                  'maja' : 5,
                  'czerwca' : 6,
                  'lipca' : 7,
                  'sierpnia': 8,
                  'września' : 9,
                  'października': 10,
                  'listopada' : 11,
                  'grudnia': 12                 
                 }
    day, month, year, *_ = date_str.split()
    return pd.datetime(int(year), int(month_dict[month]), int(day))

# %% [raw]
# def date_parser(date_str):
#
#     month_dict = ['stycznia',
#                   'lutego',
#                   'marca',
#                   'kwietnia',
#                   'maja',
#                   'czerwca',
#                   'lipca',
#                   'sierpnia',
#                   'września',
#                   'października',
#                   'listopada',
#                   'grudnia'
#                  ]
#     day, month, year, *_ = date_str.split()
#     return pd.datetime(int(year), int(month_dict.index(month)), int(day))

# %%
voting_df['Data'] = voting_df.iloc[:,1].apply(date_parser)

# %%
voting_df
# Out:
#      Nr pos. Sejmu          Data pos. Sejmu  Liczba gÅosowaÅ  \
# 0             86.0      11 września 2019 r.                 88
# 1             86.0  16 października 2019 r.                 38
# 2             85.0         31 lipca 2019 r.                 24
# 3             85.0       9 sierpnia 2019 r.                 11
# 4             85.0      30 sierpnia 2019 r.                 38
# 5             84.0         17 lipca 2019 r.                  7
# 6             84.0         19 lipca 2019 r.                169
# 7             83.0          3 lipca 2019 r.                  7
# 8             83.0          4 lipca 2019 r.                111
# 9             82.0       12 czerwca 2019 r.                  6
# 10            82.0       13 czerwca 2019 r.                126
# 11            81.0          15 maja 2019 r.                  6
# 12            81.0          16 maja 2019 r.                 92
# 13            80.0      12 kwietnia 2019 r.                 26
# 14            80.0      25 kwietnia 2019 r.                 54
# 15            79.0       3 kwietnia 2019 r.                  1
# 16            79.0       4 kwietnia 2019 r.                 49
# 17            78.0         14 marca 2019 r.                  2
# 18            78.0         15 marca 2019 r.                 68
# 19            77.0      30 stycznia 2019 r.                 33
# 20            77.0        20 lutego 2019 r.                 21
# 21            77.0        21 lutego 2019 r.                112
# 22            76.0      16 stycznia 2019 r.                440
# 23            76.0      17 stycznia 2019 r.                 22
# 24            75.0       28 grudnia 2018 r.                 15
# 25            74.0       12 grudnia 2018 r.                  3
# 26            74.0       14 grudnia 2018 r.                 66
# 27            73.0        5 grudnia 2018 r.                  5
# 28            73.0        6 grudnia 2018 r.                 50
# 29            72.0     21 listopada 2018 r.                 13
# ..             ...                      ...                ...
# 149           15.0       1 kwietnia 2016 r.                 13
# 150           14.0         16 marca 2016 r.                  5
# 151           14.0         17 marca 2016 r.                  1
# 152           14.0         18 marca 2016 r.                 46
# 153           13.0          9 marca 2016 r.                  2
# 154           13.0         11 marca 2016 r.                 43
# 155           12.0        25 lutego 2016 r.                 35
# 156           12.0        26 lutego 2016 r.                  4
# 157           11.0         9 lutego 2016 r.                  3
# 158           11.0        11 lutego 2016 r.                 36
# 159           10.0      28 stycznia 2016 r.                153
# 160           10.0      29 stycznia 2016 r.                218
# 161            8.0      14 stycznia 2016 r.                  5
# 162            8.0      15 stycznia 2016 r.                 20
# 163            7.0       29 grudnia 2015 r.                 43
# 164            7.0       30 grudnia 2015 r.                 32
# 165            6.0       21 grudnia 2015 r.                  4
# 166            6.0       22 grudnia 2015 r.                 68
# 167            5.0       15 grudnia 2015 r.                  1
# 168            5.0       16 grudnia 2015 r.                 27
# 169            5.0       17 grudnia 2015 r.                 14
# 170            4.0        9 grudnia 2015 r.                  7
# 171            4.0       10 grudnia 2015 r.                  4
# 172            3.0        2 grudnia 2015 r.                 13
# 173            2.0     25 listopada 2015 r.                 29
# 174            1.0     12 listopada 2015 r.                  8
# 175            1.0     13 listopada 2015 r.                  4
# 176            1.0     16 listopada 2015 r.                  7
# 177            1.0     18 listopada 2015 r.                 26
# 178            1.0     19 listopada 2015 r.                 33
#
#                                                   Link       Data
# 0    https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-09-11
# 1    https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-10-16
# 2    https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-07-31
# 3    https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-08-09
# 4    https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-08-30
# 5    https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-07-17
# 6    https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-07-19
# 7    https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-07-03
# 8    https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-07-04
# 9    https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-06-12
# 10   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-06-13
# 11   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-05-15
# 12   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-05-16
# 13   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-04-12
# 14   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-04-25
# 15   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-04-03
# 16   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-04-04
# 17   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-03-14
# 18   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-03-15
# 19   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-01-30
# 20   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-02-20
# 21   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-02-21
# 22   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-01-16
# 23   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2019-01-17
# 24   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2018-12-28
# 25   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2018-12-12
# 26   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2018-12-14
# 27   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2018-12-05
# 28   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2018-12-06
# 29   https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2018-11-21
# ..                                                 ...        ...
# 149  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-04-01
# 150  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-03-16
# 151  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-03-17
# 152  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-03-18
# 153  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-03-09
# 154  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-03-11
# 155  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-02-25
# 156  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-02-26
# 157  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-02-09
# 158  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-02-11
# 159  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-01-28
# 160  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-01-29
# 161  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-01-14
# 162  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2016-01-15
# 163  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-12-29
# 164  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-12-30
# 165  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-12-21
# 166  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-12-22
# 167  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-12-15
# 168  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-12-16
# 169  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-12-17
# 170  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-12-09
# 171  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-12-10
# 172  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-12-02
# 173  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-11-25
# 174  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-11-12
# 175  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-11-13
# 176  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-11-16
# 177  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-11-18
# 178  https://www.sejm.gov.pl/Sejm8.nsf/agent.xsp?sy... 2015-11-19
#
# [179 rows x 5 columns]

# %%
voting_df.to_csv('voting.csv')
