# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# # Wczytywanie pliku z przepisami

# %%
with open('data/przepisy.json') as json_file:
    recipes = json.load(json_file)

# %%
len(recipes)
# Out:
# 10175

# %% [markdown]
# ## Wyciąganie składników z przepisów

# %%
ingredients = []

for recipe in recipes:
    for ingredient in recipe['ingredient_list']:
        ingredients.append([ recipe['url'], ingredient['ingredient_name'], 
                            ingredient['ingredient_amount'],
                            ingredient['ingredient_unit']])

# %%
len(ingredients)
# Out:
# 85290

# %%
df = pd.DataFrame(ingredients, columns=["URL", "nazwa", "ilosc", "jednostka"])

# %%
df.sample(5)
# Out:
#                                                      URL  \
# 19650  https://www.przepisy.pl/przepis/mintaj-zapieka...
# 75142    https://www.przepisy.pl/przepis/pasztet-z-jajek
# 47232  https://www.przepisy.pl/przepis/salatka-z-kurc...
# 34809  https://www.przepisy.pl/przepis/ryba-na-ostro-...
# 29177  https://www.przepisy.pl/przepis/zapiekany-loso...
#
#                                  nazwa ilosc jednostka
# 19650    tłuszcz do wysmarowania formy  None      None
# 75142                           pieprz     1  szczypta
# 47232                     cebula biała     1       szt
# 34809  filety z białej ryby, np. dorsz   500         g
# 29177                           cebula     1       szt

# %%
df['nazwa_sm'] = df['nazwa'].map(lambda x: x.lower())

# %% [markdown]
# ## Co mamy w danych?

# %%
df['nazwa'].value_counts().shape
# Out:
# (9373,)

# %%
df['nazwa_sm'].value_counts().shape
# Out:
# (9340,)

# %%
df['ilosc'].value_counts().head(10)
# Out:
# 1      29735
# 2      12189
# 3       4906
# 4       4315
# 0,5     3815
# 100     3399
# 200     2635
# 50      1856
# 500     1600
# 300     1600
# Name: ilosc, dtype: int64

# %%
df['jednostka'].value_counts()
# Out:
# szt         27817
# g           14780
# łyżki        8645
# ml           4629
# szczypta     4592
# łyżka        3788
# łyżeczka     2293
# szklanki     1823
# opak         1747
# pęczek       1601
# kg           1538
# dag          1533
# szklanka     1351
# łyżeczki     1240
# łyżek         864
# pęczka        724
# szczypty      655
# l             626
# plastry       295
# plastrów      249
# garść         105
# ziarna         71
# łyżeczek       65
# puszka         64
# cm             51
# ziaren         51
# słoik          48
# pęczki         48
# plaster        36
# listków        24
# szczypt        24
# listki         22
# szklanek       20
# ziarno         18
# puszki          9
# plastra         8
# listek          4
# pęczków         2
# słoiki          2
# Name: jednostka, dtype: int64

# %% [markdown]
# ## Sprawdzanie podobieństwa nazw produktów

# %%
# pip install python-Levenshtein
import difflib
import Levenshtein

# %%
difflib.SequenceMatcher(None, "Pomidory w puszce", "Pomidory krojone").ratio() #the bigger the better
# Out:
# 0.6060606060606061

# %%
Levenshtein.distance("Pomidory krojone", "pomidory w puszce") #the smaller the better
# Out:
# 8

# %%
difflib.SequenceMatcher(None, "Pomidory", "Papryka").ratio()
# Out:
# 0.4

# %% [markdown]
# ## Wybranie unikalnych nazw i zapisanie do pomocniczej tabeli

# %%
unique_names = df['nazwa_sm'].unique()

# %%
unique_names
# Out:
# array(['makaron świderki', 'filet z kurczaka ', 'cebula', ...,
#        'pasta z czerwonej papryki', 'ostra i słodka papryka',
#        'grzyby mun wcześniej ugotowane'], dtype=object)

# %%
def find_similar(ingredient):
    for name in unique_names:
        match = difflib.SequenceMatcher(None, ingredient, name).ratio()
        if match > 0.6:
            print(name, match)

# %%
find_similar("szalotka")
# Out:
# szalotki 0.875
# mała szalotka 0.7619047619047619
# cebule szalotki 0.6086956521739131
# szalotka 1.0
# cebula szalotka 0.6956521739130435
# cebulka szalotka 0.6666666666666666
# uszka 0.6153846153846154
# salsa 0.6153846153846154
# szynka lub łopatka 0.6153846153846154
# saletra 0.6666666666666666
# kaszanka 0.625
# natka 0.6153846153846154
# sałatka: 0.625
# serwatka 0.625
# 1 szalotka 0.8888888888888888
# szalotka mała  0.7272727272727273

# %%
find_similar("pomidor")
# Out:
# pomidor 1.0
# pomidory suszone 0.6086956521739131
# pomidory 0.9333333333333333
# suszone pomidory 0.6086956521739131
# sos pomidorowy 0.6666666666666666
# pomidory pelati 0.6363636363636364
# pomidory pelatti 0.6086956521739131
# małe pomidory 0.7
# dojrzały pomidor 0.6086956521739131
# duże pomidory 0.7
# średnie pomidory 0.6086956521739131
# sok pomidorowy 0.6666666666666666
# pomidory cherry  0.6086956521739131
# pomidor suszony 0.6363636363636364
# puszka pomidorów 0.6086956521739131
# pomidory świeże  0.6086956521739131
# pasta pomidorowa 0.6086956521739131
# średni pomidor  0.6363636363636364
# świeże pomidory 0.6363636363636364
# pomidor malinowy 0.6086956521739131
# pomidory średnie 0.6086956521739131
# pomidory pellati 0.6086956521739131
# pomidor średni  0.6363636363636364
# pomidory duże  0.6666666666666666
# żółty pomidor 0.7
# pomidorowe puree 0.6086956521739131
# suszony pomidor 0.6363636363636364
# duży pomidor  0.7
# puree pomidorowe 0.6086956521739131
# twardy pomidor 0.6666666666666666
# pomidory małe 0.7
# świeży pomidor 0.6666666666666666
# mały pomidor 0.7368421052631579
# pomidor mały 0.7368421052631579
# pomidor świeży 0.6666666666666666
# pomiodory 0.875
# krojone pomidory 0.6086956521739131
# średni pomidor 0.6666666666666666
# pomidory starte  0.6086956521739131
# obrane pomidory  0.6086956521739131
# pulpa pomidorowa 0.6086956521739131
# pomidor duży 0.7368421052631579
# pomidor żółty 0.7
# pomiodor  0.875
# 1 pomidor  0.8235294117647058
# pomidor  0.9333333333333333
# 350 g pomidorów 0.6363636363636364
# pomidor z puszki 0.6086956521739131

# %% [markdown]
# ## Losowanie składników do analizy

# %%
import random

# %%
random.choices(unique_names, k=40)
# Out:
# ['oliwki zielone, pokrojone w krążki',
#  'płatki owsiane błyskawiczne',
#  'świeże czerwone chili',
#  'duży kawałek pancetty ',
#  'malutki ząbek czosnku',
#  'orzechówka',
#  'ryż do sushi',
#  'sos chilli z czosnkiem ',
#  'oliwki zielone bez pestek',
#  'ostra zielona papryczka',
#  'ostra musztarda',
#  'czerstwy bochenek chleba tostowego ',
#  'pszenny chleb',
#  'azjatycka mieszanka warzyw (mrożonych)',
#  'jabłka kwaśne ',
#  'śmietanka kokosowa ',
#  'suszone mięso wołowe',
#  'chudy ser twarogowy',
#  'kwaśna śmietana 12%',
#  '180 g gotowanej szynki (może być parmeńska) pokrojonej w cienkie paseczki',
#  'ocet biały winny delikatny np. jabłkowy',
#  'groch (najlepiej cały, niełuskany)',
#  'płat ciasta francuskiego',
#  '2 duże czerwone papryki',
#  'oliwki czarne, pokrojone w krążki',
#  'pstrąg świeży',
#  'filet z morskiej ryby ',
#  'bułka tarta lub typu panko',
#  'mięso mielone jagnięce',
#  'podudzia z kurczaka bez skóry i kości lub piersi z kurczaka',
#  'wieprzowina szynkowa w plastrach ',
#  'kiełki bambusa z puszki ',
#  'pomarańczowy ser cheddar',
#  'sok i skórka z cytryny',
#  'ciepła, przegotowana woda',
#  'imbir świeży posiekany',
#  'saletra (do nabycia w aptece)',
#  '425 ml mleka pół na pół ze śmietaną 36',
#  'nasiona kopru włoskiego',
#  'mała grillowana pierś z kurczaka']

# %% [markdown]
# ## Generowanie listy unikalnych słów które użyte są w nazwach składników

# %%
def remove_unwanted_chars(str):
    pass

# %%
import re
from operator import itemgetter

words = []
counts = []
stop_words = ["", "z", "w", "lub", "do", "i", "bez", "-", "świeży", "np.", "na", "g", "mała", "np",
             "suszone", "puszki", "pokrojona", "czerwona", "świeże", "zielona", "kilka", "kostkę",
             "pokrojone", "biała", "ze", "żółty", "mały", "świeża", "pęczek", "dekoracja",
             "duże", "mrożone", "knorr"]

# find unique words and count occurences
for name in unique_names:
    for word in re.sub('[^a-ząćęółżźśń ]+', '', name).split(" "):
        if word in stop_words:
            pass
        else:
            if word in words:
                counts[words.index(word)] += 1
            else:
                words.append(word)
                counts.append(1)
                
# create list of words and counts
word_count = []

for i in range(0,len(words)):
    word_count.append([words[i], counts[i]])

# sort the list and reverse it
word_count_sorted = sorted(word_count, key=itemgetter(1))
word_count_sorted.reverse()

len(word_count_sorted)
# Out:
# 3516

# %%
word_count_sorted
# Out:
# [['ser', 323],
#  ['makaron', 215],
#  ['mięso', 205],
#  ['papryka', 202],
#  ['kurczaka', 199],
#  ['cebula', 132],
#  ['pomidory', 127],
#  ['sos', 113],
#  ['chili', 112],
#  ['filet', 110],
#  ['filety', 107],
#  ['mielone', 100],
#  ['sok', 98],
#  ['szynka', 98],
#  ['ryż', 97],
#  ['grzyby', 95],
#  ['puszka', 95],
#  ['starty', 93],
#  ['plastry', 92],
#  ['kości', 91],
#  ['śmietana', 90],
#  ['małe', 88],
#  ['ziemniaki', 88],
#  ['fasola', 87],
#  ['liście', 86],
#  ['posiekana', 85],
#  ['kromki', 83],
#  ['pieprz', 80],
#  ['natka', 79],
#  ['papryczka', 78],
#  ['pietruszki', 78],
#  ['sałata', 77],
#  ['chilli', 76],
#  ['przyprawa', 75],
#  ['najlepiej', 75],
#  ['typu', 74],
#  ['wędzony', 73],
#  ['olej', 72],
#  ['kapusta', 71],
#  ['kiełbasa', 71],
#  ['krewetki', 68],
#  ['boczek', 65],
#  ['dekoracji', 63],
#  ['smaku', 63],
#  ['cytryny', 62],
#  ['zielone', 61],
#  ['mąka', 61],
#  ['skóry', 60],
#  ['orzechy', 60],
#  ['czerwone', 60],
#  ['indyka', 60],
#  ['chleb', 58],
#  ['wieprzowe', 58],
#  ['chleba', 57],
#  ['ostra', 57],
#  ['czosnku', 57],
#  ['łososia', 56],
#  ['ugotowany', 56],
#  ['mieszanka', 56],
#  ['bułka', 56],
#  ['zielony', 55],
#  ['serek', 55],
#  ['łosoś', 55],
#  ['pierś', 54],
#  ['wołowina', 53],
#  ['oliwa', 53],
#  ['groszek', 53],
#  ['wędzona', 53],
#  ['gałązka', 52],
#  ['kawałek', 52],
#  ['główka', 52],
#  ['średniej', 52],
#  ['ugotowane', 52],
#  ['piersi', 52],
#  ['papryki', 51],
#  ['puszce', 51],
#  ['parmezan', 51],
#  ['pokrojony', 51],
#  ['pieczarki', 51],
#  ['posiekany', 51],
#  ['seler', 50],
#  ['czosnek', 50],
#  ['biały', 50],
#  ['wielkości', 50],
#  ['mrożony', 50],
#  ['posiekane', 49],
#  ['kurczak', 49],
#  ['świeżego', 48],
#  ['skórka', 48],
#  ['oliwki', 48],
#  ['mrożona', 48],
#  ['garść', 48],
#  ['duża', 48],
#  ['pasta', 47],
#  ['słodka', 47],
#  ['fasolka', 47],
#  ['wołowe', 47],
#  ['kasza', 46],
#  ['mielony', 46],
#  ['jogurt', 46],
#  ['wieprzowa', 46],
#  ['białe', 45],
#  ['marchewka', 44],
#  ['ugotowana', 43],
#  ['łyżki', 43],
#  ['zalewie', 43],
#  ['mini', 42],
#  ['ryby', 42],
#  ['być', 42],
#  ['suszona', 42],
#  ['plastrach', 42],
#  ['mielona', 41],
#  ['o', 41],
#  ['pietruszka', 41],
#  ['mozzarella', 41],
#  ['papryczki', 40],
#  ['pestek', 40],
#  ['imbir', 40],
#  ['kiełki', 40],
#  ['ogórek', 40],
#  ['marynowane', 39],
#  ['ok', 39],
#  ['wino', 39],
#  ['obrane', 39],
#  ['bazylii', 39],
#  ['drobno', 38],
#  ['kapusty', 38],
#  ['oliwek', 38],
#  ['świeżej', 38],
#  ['mleko', 38],
#  ['ryba', 37],
#  ['por', 37],
#  ['pomidor', 37],
#  ['ml', 36],
#  ['kromka', 36],
#  ['wieprzowina', 36],
#  ['łopatka', 36],
#  ['masło', 36],
#  ['gałązki', 35],
#  ['ziarna', 35],
#  ['duży', 35],
#  ['sałaty', 35],
#  ['śliwki', 35],
#  ['ocet', 35],
#  ['schab', 35],
#  ['udka', 34],
#  ['kolendry', 34],
#  ['ogórki', 34],
#  ['oleju', 34],
#  ['jajka', 34],
#  ['woda', 34],
#  ['łyżka', 33],
#  ['średnie', 33],
#  ['ciasto', 33],
#  ['szparagowa', 33],
#  ['kostka', 32],
#  ['tarty', 32],
#  ['selera', 32],
#  ['żółta', 32],
#  ['koperek', 32],
#  ['ząbek', 32],
#  ['słoik', 31],
#  ['listki', 31],
#  ['czarny', 31],
#  ['pół', 30],
#  ['młode', 30],
#  ['białej', 30],
#  ['dynia', 30],
#  ['włoskie', 30],
#  ['pieczywo', 30],
#  ['marchew', 30],
#  ['inny', 30],
#  ['szpinak', 30],
#  ['kukurydza', 30],
#  ['natki', 29],
#  ['surowy', 29],
#  ['limonki', 29],
#  ['naturalny', 29],
#  ['ząbki', 29],
#  ['kolendra', 29],
#  ['surowe', 29],
#  ['imbiru', 28],
#  ['dymka', 28],
#  ['orzeszki', 28],
#  ['cebule', 28],
#  ['dorsza', 28],
#  ['wędzonego', 27],
#  ['sera', 27],
#  ['steki', 27],
#  ['pomidorów', 27],
#  ['listków', 27],
#  ['tuńczyk', 27],
#  ['jabłka', 27],
#  ['suszony', 27],
#  ['cukinia', 27],
#  ['karkówka', 27],
#  ['sól', 27],
#  ['plasterki', 26],
#  ['proszku', 26],
#  ['tymianek', 26],
#  ['cm', 26],
#  ['prawdziwki', 26],
#  ['udziec', 26],
#  ['słonecznika', 26],
#  ['bulion', 26],
#  ['fasoli', 26],
#  ['świeżo', 26],
#  ['gałązek', 26],
#  ['konserwowa', 26],
#  ['pomidorki', 26],
#  ['jabłko', 26],
#  ['cebulka', 25],
#  ['starta', 25],
#  ['posiekanej', 25],
#  ['soczewica', 25],
#  ['skórki', 25],
#  ['płatki', 25],
#  ['warzyw', 25],
#  ['bazylia', 25],
#  ['cienkie', 25],
#  ['wędzone', 25],
#  ['musztarda', 25],
#  ['jajko', 25],
#  ['podania', 24],
#  ['curry', 24],
#  ['marynowana', 24],
#  ['polędwica', 24],
#  ['migdały', 24],
#  ['czarne', 24],
#  ['rostbef', 24],
#  ['smażenia', 24],
#  ['pomidorowy', 24],
#  ['świderki', 24],
#  ['oliwy', 23],
#  ['paski', 23],
#  ['młoda', 23],
#  ['ryżowy', 23],
#  ['ananas', 23],
#  ['kotlety', 23],
#  ['chorizo', 23],
#  ['cukier', 23],
#  ['może', 23],
#  ['gotowana', 23],
#  ['śledzie', 23],
#  ['cytryna', 23],
#  ['kalafior', 23],
#  ['gotowe', 23],
#  ['szparagi', 22],
#  ['po', 22],
#  ['kozi', 22],
#  ['nasiona', 22],
#  ['inna', 22],
#  ['wołowy', 22],
#  ['strąk', 22],
#  ['bułki', 22],
#  ['sojowy', 22],
#  ['szczypiorek', 22],
#  ['kwaśna', 22],
#  ['białego', 21],
#  ['sucha', 21],
#  ['szynki', 21],
#  ['opakowanie', 21],
#  ['śmietanka', 21],
#  ['oregano', 21],
#  ['cheddar', 21],
#  ['buraki', 21],
#  ['twardy', 21],
#  ['chrzan', 21],
#  ['pszenna', 21],
#  ['prażone', 20],
#  ['bagietka', 20],
#  ['ryżu', 20],
#  ['średnia', 20],
#  ['mogą', 20],
#  ['wcześniej', 20],
#  ['podgrzybki', 20],
#  ['tortilla', 20],
#  ['tagliatelle', 20],
#  ['chudy', 20],
#  ['cebulki', 19],
#  ['tuńczyka', 19],
#  ['kukurydzy', 19],
#  ['boczku', 19],
#  ['koperku', 19],
#  ['wytrawne', 19],
#  ['albo', 19],
#  ['dyni', 19],
#  ['część', 19],
#  ['rozmaryn', 19],
#  ['otarta', 19],
#  ['jalapeno', 19],
#  ['wywar', 19],
#  ['namoczone', 19],
#  ['penne', 19],
#  ['feta', 19],
#  ['tarta', 19],
#  ['skórą', 18],
#  ['stek', 18],
#  ['pszenne', 18],
#  ['oczyszczone', 18],
#  ['dorsz', 18],
#  ['owoce', 18],
#  ['ostry', 18],
#  ['czerwonej', 18],
#  ['twaróg', 18],
#  ['cielęcina', 18],
#  ['ciasta', 18],
#  ['naciowy', 18],
#  ['chuda', 18],
#  ['wieprzowy', 18],
#  ['zioła', 18],
#  ['wołowa', 18],
#  ['rosołu', 18],
#  ['warzywa', 18],
#  ['dojrzałe', 18],
#  ['placki', 18],
#  ['cherry', 18],
#  ['pleśniowy', 18],
#  ['spaghetti', 18],
#  ['brokuł', 18],
#  ['szt', 17],
#  ['ewentualnie', 17],
#  ['masła', 17],
#  ['czerwony', 17],
#  ['anchois', 17],
#  ['liści', 17],
#  ['pestki', 17],
#  ['tymianku', 17],
#  ['jagnięce', 17],
#  ['ćwiartki', 17],
#  ['suszonych', 17],
#  ['namoczona', 17],
#  ['ziarnami', 17],
#  ['gouda', 17],
#  ['dymki', 17],
#  ['opcjonalnie', 17],
#  ['winogrona', 17],
#  ['płaty', 17],
#  ['topiony', 17],
#  ['sałat', 17],
#  ['mix', 17],
#  ['łopatki', 17],
#  ['sosie', 17],
#  ['drobiowe', 17],
#  ['szalotka', 17],
#  ['posiekanych', 16],
#  ['udko', 16],
#  ['kiełbaski', 16],
#  ['kurki', 16],
#  ['ciecierzyca', 16],
#  ['pomarańczy', 16],
#  ['mięsa', 16],
#  ['mięty', 16],
#  ['ostrej', 16],
#  ['żurawina', 16],
#  ['korzeń', 16],
#  ['rurki', 16],
#  ['gram', 16],
#  ['ciemne', 16],
#  ['wątróbka', 16],
#  ['chińska', 16],
#  ['ziemne', 16],
#  ['pekińska', 16],
#  ['gęsty', 16],
#  ['dżem', 16],
#  ['makaronu', 15],
#  ['młody', 15],
#  ['wina', 15],
#  ['karp', 15],
#  ['leśne', 15],
#  ['tostowego', 15],
#  ['twarożek', 15],
#  ['pstrąg', 15],
#  ['różyczki', 15],
#  ['włoskiego', 15],
#  ['brązowy', 15],
#  ['surowa', 15],
#  ['groch', 15],
#  ['jagnięcina', 15],
#  ['roślinny', 15],
#  ['ementaler', 15],
#  ['kostkach', 14],
#  ['śmietany', 14],
#  ['polędwicy', 14],
#  ['kawałki', 14],
#  ['sezamu', 14],
#  ['drobiowa', 14],
#  ['pomarańczowy', 14],
#  ['bób', 14],
#  ['łodyga', 14],
#  ['rukola', 14],
#  ['krojone', 14],
#  ['gryczana', 14],
#  ['gotowane', 14],
#  ['jęczmienna', 14],
#  ['marchewki', 14],
#  ['tłuszcz', 14],
#  ['miód', 14],
#  ['borowiki', 14],
#  ['kremowy', 14],
#  ['majeranek', 14],
#  ['konserwowy', 14],
#  ['lodowa', 14],
#  ['koktajlowe', 14],
#  ['light', 14],
#  ['przecier', 14],
#  ['łyżek', 13],
#  ['siekana', 13],
#  ['ryb', 13],
#  ['pęczka', 13],
#  ['pepperoni', 13],
#  ['pokrojonych', 13],
#  ['szklanki', 13],
#  ['wędlina', 13],
#  ['słodkie', 13],
#  ['kłącze', 13],
#  ['grubo', 13],
#  ['soli', 13],
#  ['pieczywa', 13],
#  ['skórką', 13],
#  ['kością', 13],
#  ['orzechów', 13],
#  ['tostowy', 13],
#  ['włoska', 13],
#  ['kaczki', 13],
#  ['kurze', 13],
#  ['kopru', 13],
#  ['wodzie', 13],
#  ['czarna', 13],
#  ['marynowany', 13],
#  ['średni', 13],
#  ['kiszone', 13],
#  ['margaryna', 13],
#  ['sałatkowy', 13],
#  ['naciowego', 13],
#  ['jaja', 13],
#  ['grzanki', 13],
#  ['pieczenia', 13],
#  ['golonka', 13],
#  ['razowy', 13],
#  ['cielęce', 13],
#  ['zielonej', 13],
#  ['koncentrat', 13],
#  ['kapary', 13],
#  ['twardo', 13],
#  ['kwaśne', 13],
#  ['małże', 12],
#  ['pstrąga', 12],
#  ['pokrojonego', 12],
#  ['sałatka', 12],
#  ['otręby', 12],
#  ['cząstki', 12],
#  ['gruszki', 12],
#  ['shitake', 12],
#  ['extra', 12],
#  ['sezam', 12],
#  ['szpinaku', 12],
#  ['burak', 12],
#  ['czerwonego', 12],
#  ['słoiku', 12],
#  ['oliwie', 12],
#  ['szałwia', 12],
#  ['groszkiem', 12],
#  ['cykoria', 12],
#  ['słoiczek', 12],
#  ['mieszane', 12],
#  ['solone', 12],
#  ['karpia', 12],
#  ['cały', 12],
#  ['groszku', 12],
#  ['ziemniak', 12],
#  ['golonki', 12],
#  ['nerkowca', 12],
#  ['koper', 12],
#  ['kremówka', 12],
#  ['kiełbasy', 12],
#  ['liść', 12],
#  ['własnym', 12],
#  ['warzywna', 12],
#  ['rosołowa', 12],
#  ['porcja', 12],
#  ['śledziowe', 12],
#  ['ziemniaków', 12],
#  ['piwo', 12],
#  ['philadelphia', 12],
#  ['słoika', 12],
#  ['kawałku', 12],
#  ['kajzerka', 12],
#  ['oscypek', 12],
#  ['szalotki', 12],
#  ['puree', 11],
#  ['kury', 11],
#  ['morza', 11],
#  ['owoców', 11],
#  ['ości', 11],
#  ['paseczki', 11],
#  ['pełnoziarnisty', 11],
#  ['sojowe', 11],
#  ['pieprzu', 11],
#  ['cienka', 11],
#  ['płatkach', 11],
#  ['sosu', 11],
#  ['obrana', 11],
#  ['paczka', 11],
#  ['każdy', 11],
#  ['salami', 11],
#  ['ostre', 11],
#  ['tofu', 11],
#  ['całości', 11],
#  ['kulki', 11],
#  ['udźca', 11],
#  ['ziarenka', 11],
#  ['grubości', 11],
#  ['użyć', 11],
#  ['drobiowy', 11],
#  ['pita', 11],
#  ['rozmarynu', 11],
#  ['kokosowe', 11],
#  ['gęsta', 11],
#  ['włoszczyzna', 11],
#  ['żeberka', 11],
#  ['tłuszczu', 11],
#  ['drobną', 11],
#  ['bakłażan', 11],
#  ['rama', 11],
#  ['śledź', 11],
#  ['oczyszczona', 11],
#  ['brokuły', 11],
#  ['szczypiorkiem', 11],
#  ['rzymska', 11],
#  ['słonina', 11],
#  ['cukru', 10],
#  ['suchy', 10],
#  ['fix', 10],
#  ['grube', 10],
#  ['jagnięcy', 10],
#  ['krem', 10],
#  ['jagnięca', 10],
#  ['plastrów', 10],
#  ['pieczona', 10],
#  ['słupki', 10],
#  ['zmielone', 10],
#  ['razowego', 10],
#  ['wstążki', 10],
#  ['karbowana', 10],
#  ['hellmanns', 10],
#  ['można', 10],
#  ['boczniaki', 10],
#  ['syrop', 10],
#  ['mango', 10],
#  ['cała', 10],
#  ['warzywny', 10],
#  ['kukurydziana', 10],
#  ['główki', 10],
#  ['cytrynowa', 10],
#  ['tabasco', 10],
#  ['mięta', 10],
#  ['szczypta', 10],
#  ['mun', 10],
#  ['chiński', 10],
#  ['balsamiczny', 10],
#  ['czerstwa', 10],
#  ['polędwiczki', 10],
#  ['polędwiczka', 10],
#  ['mąki', 10],
#  ['chipsy', 10],
#  ['śmietankowy', 10],
#  ['papryką', 10],
#  ['piniowe', 10],
#  ['konserwowe', 10],
#  ['startego', 9],
#  ['pokrojonej', 9],
#  ['okoń', 9],
#  ['półtłusty', 9],
#  ['pieczarek', 9],
#  ['pieczony', 9],
#  ['nie', 9],
#  ['bułeczki', 9],
#  ['słodki', 9],
#  ['sandacz', 9],
#  ['lazur', 9],
#  ['dzwonka', 9],
#  ['kawałkach', 9],
#  ['zalewy', 9],
#  ['ananasa', 9],
#  ['sambal', 9],
#  ['tortille', 9],
#  ['cielęca', 9],
#  ['kolorowy', 9],
#  ['pory', 9],
#  ['kulka', 9],
#  ['fasolki', 9],
#  ['ciemna', 9],
#  ['listek', 9],
#  ['łyżeczka', 9],
#  ['risotto', 9],
#  ['ogórków', 9],
#  ['winogron', 9],
#  ['włoski', 9],
#  ['bambusa', 9],
#  ['ciabatta', 9],
#  ['rokpol', 9],
#  ['innej', 9],
#  ['pomarańczowa', 9],
#  ['lubczyk', 9],
#  ['upieczone', 9],
#  ['części', 9],
#  ['twarogowy', 9],
#  ['sezamowy', 9],
#  ['winny', 9],
#  ['plaster', 9],
#  ['ciemny', 9],
#  ['ziół', 9],
#  ['brzoskwinie', 9],
#  ['pomidorowego', 9],
#  ['octu', 9],
#  ['podudzia', 9],
#  ['kuskus', 9],
#  ['poszatkowana', 9],
#  ['tortellini', 9],
#  ['łodygi', 9],
#  ['smalec', 9],
#  ['kg', 9],
#  ['muszle', 9],
#  ['szczypior', 9],
#  ['mleku', 9],
#  ['miąższ', 9],
#  ['długoziarnisty', 9],
#  ['żółtka', 9],
#  ['majonez', 9],
#  ['drożdże', 9],
#  ['dużych', 9],
#  ['grzybów', 9],
#  ['virgine', 8],
#  ['konserwowej', 8],
#  ['comber', 8],
#  ['łuskane', 8],
#  ['konfitura', 8],
#  ['krążki', 8],
#  ['karkówki', 8],
#  ['plasterkach', 8],
#  ['karczochy', 8],
#  ['perłowa', 8],
#  ['kiełków', 8],
#  ['jałowca', 8],
#  ['szałwii', 8],
#  ['kolby', 8],
#  ['gorczycy', 8],
#  ['sezamem', 8],
#  ['morska', 8],
#  ['paluszki', 8],
#  ['rostbefu', 8],
#  ['ulubione', 8],
#  ['posiekanego', 8],
#  ['gotowany', 8],
#  ['mozzarelli', 8],
#  ['panierowania', 8],
#  ['rosół', 8],
#  ['szklanka', 8],
#  ['ziołami', 8],
#  ['mintaja', 8],
#  ['sandacza', 8],
#  ['zmielona', 8],
#  ['waniliowy', 8],
#  ['brokuła', 8],
#  ['parmeńska', 8],
#  ['torebka', 8],
#  ['tylko', 8],
#  ['pora', 8],
#  ['pikantna', 8],
#  ['posypania', 8],
#  ['grecki', 8],
#  ['rodzynki', 8],
#  ['awokado', 8],
#  ['kropel', 8],
#  ['makrela', 8],
#  ['nachos', 8],
#  ['niebieski', 8],
#  ['kura', 8],
#  ['pełnoziarniste', 8],
#  ['blue', 8],
#  ['arborio', 8],
#  ['kiszona', 8],
#  ['nieduży', 8],
#  ['jasne', 8],
#  ['pelatti', 8],
#  ['rzepakowy', 8],
#  ['grillowana', 8],
#  ['tłusty', 8],
#  ['jabłkowy', 8],
#  ['obranych', 7],
#  ['musztardy', 7],
#  ['czosnkiem', 7],
#  ['masa', 7],
#  ['wody', 7],
#  ['sardynki', 7],
#  ['tajski', 7],
#  ['kurek', 7],
#  ['czerstwy', 7],
#  ['woreczek', 7],
#  ['pasztet', 7],
#  ['drobna', 7],
#  ['wiejski', 7],
#  ['jajek', 7],
#  ['cytrynowy', 7],
#  ['szczupak', 7],
#  ['mule', 7],
#  ['gęsi', 7],
#  ['wołowej', 7],
#  ['posmarowania', 7],
#  ['chrzanu', 7],
#  ['żytniego', 7],
#  ['porzeczki', 7],
#  ['gr', 7],
#  ['homogenizowany', 7],
#  ['śledzia', 7],
#  ['winne', 7],
#  ['mintaj', 7],
#  ['pszenny', 7],
#  ['rzodkiewki', 7],
#  ['chude', 7],
#  ['razowa', 7],
#  ['gotowy', 7],
#  ['inne', 7],
#  ['oelek', 7],
#  ['kaffir', 7],
#  ['hokkaido', 7],
#  ['zmielony', 7],
#  ['baranina', 7],
#  ['czosnkowy', 7],
#  ['miękki', 7],
#  ['od', 7],
#  ['rydze', 7],
#  ['pełnoziarnista', 7],
#  ['głowa', 7],
#  ['maślaki', 7],
#  ['czarnych', 7],
#  ['krabowe', 7],
#  ['creme', 7],
#  ['angielskie', 7],
#  ['ziele', 7],
#  ['gorgonzola', 7],
#  ['radicchio', 7],
#  ['lollo', 7],
#  ['wysmarowania', 7],
#  ['ziaren', 7],
#  ['cynamonu', 7],
#  ['żółte', 7],
#  ['włoskich', 7],
#  ['jaś', 7],
#  ['również', 7],
#  ['pinii', 7],
#  ['jaśminowy', 7],
#  ['piórka', 7],
#  ['formy', 7],
#  ['włoskiej', 7],
#  ['ziemniaczana', 7],
#  ['pesto', 7],
#  ['pomarańcza', 7],
#  ['cebuli', 7],
#  ['lasagne', 7],
#  ['kostką', 7],
#  ['basmati', 7],
#  ['owsiane', 7],
#  ['muszelki', 7],
#  ['rybny', 7],
#  ['mleka', 7],
#  ['tortilli', 7],
#  ['chipotle', 7],
#  ['żółtko', 7],
#  ['około', 7],
#  ['kość', 7],
#  ['francuskie', 7],
#  ['tostowe', 7],
#  ['lodowej', 7],
#  ['matias', 7],
#  ['rukoli', 7],
#  ['mrożonych', 7],
#  ['jajeczny', 7],
#  ['kiszony', 7],
#  ['pałki', 7],
#  ['pęczak', 7],
#  ['mozarella', 7],
#  ['siekany', 6],
#  ['marynata', 6],
#  ['tarce', 6],
#  ['syropie', 6],
#  ['halibut', 6],
#  ['estragonu', 6],
#  ['okonia', 6],
#  ['morskiej', 6],
#  ['szyjki', 6],
#  ['strączki', 6],
#  ['cielęcy', 6],
#  ['filetów', 6],
#  ['mięs', 6],
#  ['wątróbki', 6],
#  ['razem', 6],
#  ['meksykańska', 6],
#  ['bochenek', 6],
#  ['gulasz', 6],
#  ['fettuccine', 6],
#  ['siekane', 6],
#  ['pstrągi', 6],
#  ['tajska', 6],
#  ['solą', 6],
#  ['cienki', 6],
#  ['tosty', 6],
#  ['śląska', 6],
#  ['żółtego', 6],
#  ['jagody', 6],
#  ['gotowania', 6],
#  ['wiśnie', 6],
#  ['bataty', 6],
#  ['wasabi', 6],
#  ['majeranku', 6],
#  ['szponder', 6],
#  ['białko', 6],
#  ['porcje', 6],
#  ['pełnoziarnistego', 6],
#  ['smaków', 6],
#  ['dzwonki', 6],
#  ['strąki', 6],
#  ['wyciśnięty', 6],
#  ['oczyszczony', 6],
#  ['upieczony', 6],
#  ['buraczki', 6],
#  ['pikantny', 6],
#  ['cytryn', 6],
#  ['obrany', 6],
#  ['ryżowe', 6],
#  ['malinowy', 6],
#  ['fusilli', 6],
#  ['ziarnisty', 6],
#  ['greckiego', 6],
#  ['łazanki', 6],
#  ['nadziewane', 6],
#  ['kosteczkę', 6],
#  ['wiejska', 6],
#  ['kardamon', 6],
#  ['słone', 6],
#  ['kruche', 6],
#  ['pokruszony', 6],
#  ['kolorowe', 6],
#  ['pleśnią', 6],
#  ['drobny', 6],
#  ['owczy', 6],
#  ['indyk', 6],
#  ['habanero', 6],
#  ['cukinie', 6],
#  ['kalarepa', 6],
#  ['przez', 6],
#  ['słonecznik', 6],
#  ['ziarno', 6],
#  ['pokruszone', 6],
#  ['burgerów', 6],
#  ['nieduże', 6],
#  ['gnocchi', 6],
#  ['niesolone', 6],
#  ['kulkach', 6],
#  ['chińskich', 6],
#  ['kabaczek', 6],
#  ['jarmuż', 6],
#  ['schabu', 6],
#  ['połówki', 6],
#  ['angielskiego', 6],
#  ['laska', 6],
#  ['gruyer', 6],
#  ['szaszłyków', 6],
#  ['brązowa', 6],
#  ['goździki', 6],
#  ['jasny', 6],
#  ['możesz', 6],
#  ['razowe', 6],
#  ['cieciorka', 6],
#  ['skrzydełka', 6],
#  ['panko', 6],
#  ['mundurkach', 6],
#  ['szczypiorku', 6],
#  ['sparzone', 6],
#  ['zielonego', 6],
#  ['sztuk', 6],
#  ['laskowe', 6],
#  ['masala', 6],
#  ['patelnię', 6],
#  ['jajo', 6],
#  ['gałka', 6],
#  ['nitki', 6],
#  ['jednej', 6],
#  ['grzybki', 6],
#  ['słonecznikowy', 6],
#  ['soku', 6],
#  ['delikat', 6],
#  ['szczypiorem', 6],
#  ['kminek', 6],
#  ['kokardki', 6],
#  ['parówki', 6],
#  ['pelati', 6],
#  ['pętko', 6],
#  ['kajzerki', 6],
#  ['połowy', 6],
#  ['mrożonego', 6],
#  ['limonka', 6],
#  ['babuni', 6],
#  ['podudzie', 6],
#  ['ketchup', 6],
#  ['środkowy', 6],
#  ['przyprawowa', 5],
#  ['śmietanki', 5],
#  ['mm', 5],
#  ['ja', 5],
#  ['pieprzem', 5],
#  ['oraz', 5],
#  ['laski', 5],
#  ['makreli', 5],
#  ['gęsie', 5],
#  ['kostce', 5],
#  ['sprawiony', 5],
#  ['peklowana', 5],
#  ['kuchni', 5],
#  ['białych', 5],
#  ['prażona', 5],
#  ['smażona', 5],
#  ['rakowe', 5],
#  ['melon', 5],
#  ['świeżych', 5],
#  ['drobne', 5],
#  ['kraba', 5],
#  ['melasa', 5],
#  ['hiszpańska', 5],
#  ['ugotowanego', 5],
#  ['rzepa', 5],
#  ['kapelusze', 5],
#  ['same', 5],
#  ['roztrzepane', 5],
#  ['sztuki', 5],
#  ['nogi', 5],
#  ['rzymski', 5],
#  ['kmin', 5],
#  ['okrągły', 5],
#  ['bieluch', 5],
#  ['czarnej', 5],
#  ['pieczeń', 5],
#  ['czekolada', 5],
#  ['kalmary', 5],
#  ['białka', 5],
#  ['ziemniaczane', 5],
#  ['parzony', 5],
#  ['chińskie', 5],
#  ['kaparów', 5],
#  ['paprykowa', 5],
#  ['dzika', 5],
#  ['pieczarka', 5],
#  ['uniwersalna', 5],
#  ['koncentratu', 5],
#  ['utarty', 5],
#  ['bardzo', 5],
#  ['koktajlowych', 5],
#  ['halibuta', 5],
#  ['wypatroszony', 5],
#  ['grubą', 5],
#  ['całe', 5],
#  ['uda', 5],
#  ['a', 5],
#  ['głowy', 5],
#  ['parmezanu', 5],
#  ['pestkami', 5],
#  ['ogon', 5],
#  ['mandarynki', 5],
#  ['uht', 5],
#  ['truskawki', 5],
#  ['fileciki', 5],
#  ['roszponka', 5],
#  ['sherry', 5],
#  ['mascarpone', 5],
#  ['brandy', 5],
#  ['czarnego', 5],
#  ['orkiszowa', 5],
#  ['camembert', 5],
#  ['maliny', 5],
#  ['małych', 5],
#  ['drewniane', 5],
#  ['puszcze', 5],
#  ['kolanka', 5],
#  ['klarowane', 5],
#  ['pszennego', 5],
#  ['kostki', 5],
#  ['gryczany', 5],
#  ['niebieską', 5],
#  ['serrano', 5],
#  ['borówek', 5],
#  ['matiasy', 5],
#  ['margaryny', 5],
#  ['gomółka', 5],
#  ['ryżowa', 5],
#  ['szafranu', 5],
#  ['zółty', 5],
#  ['bagietki', 5],
#  ['francuskiego', 5],
#  ['łuskany', 5],
#  ...]
