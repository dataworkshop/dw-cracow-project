# %%
import pandas as pd
import json
import re

# %%
# df =pd.read_json('przepisy.json')

# %%
# df.ingredient_list[0]

# %%
with open('przepisy.json', encoding='utf8') as json_file:
    recipes = json.load(json_file)

# %%
ingredients = []
for recipe in recipes:
    for ingredient in recipe['ingredient_list']:
        ingredients.append([ recipe['url'], ingredient['ingredient_name'], 
                            ingredient['ingredient_amount'],
                            ingredient['ingredient_unit']])

# %%
df = pd.DataFrame(ingredients, columns=["URL", "nazwa", "ilosc", "jednostka"])

# %%
df.head()
# Out:
#                                                  URL              nazwa ilosc  \
# 0  https://www.przepisy.pl/przepis/zapiekanka-mak...   makaron świderki   100
# 1  https://www.przepisy.pl/przepis/zapiekanka-mak...  filet z kurczaka      1
# 2  https://www.przepisy.pl/przepis/zapiekanka-mak...             cebula     1
# 3  https://www.przepisy.pl/przepis/zapiekanka-mak...            papryka     1
# 4  https://www.przepisy.pl/przepis/zapiekanka-mak...            pomidor     1
#
#   jednostka
# 0         g
# 1       szt
# 2       szt
# 3       szt
# 4       szt

# %%
#text distance

# %%
import textdistance as td

# %%
# %pip install textdistance
# Out:
# Requirement already satisfied: textdistance in e:\anaconda\lib\site-packages (4.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# def FindSimilarIngrs(ingr, tol = .0 ):

#     similarities = []

#     for name in df['nazwa']: 
#         score = td.hamming.normalized_similarity(name,ingr)
#         if( score > tolerance ):
#             kro = (name, score)
#             if(kro not in similarities):
#                 similarities.append(kro)
#                 print( kro )
# FindSimilarIngrs('pomidor')

# %%
# tolerance = 0.7

# similarities = []

# for name in df['nazwa']: 
#     for second_name in df['nazwa']:
#         score = td.hamming.normalized_similarity(name,second_name)
#         if(score < 1 and score> tolerance):
#             kro = (name, second_name, score)
#             if(kro not in similarities):
#                 similarities.append(kro)
#                 print( kro )

# %%
unique_names = df['nazwa'].unique()

# %%
import difflib
def find_similar(ingredient):
    for name in unique_names:
        match = difflib.SequenceMatcher(None, ingredient, name).ratio()
        if match > 0.6:
            print(name, match)

            find_similar('szalotka')
# Out:
# szalotki 0.875
# mała szalotka 0.7619047619047619
# cebule szalotki 0.6086956521739131
# szalotka 1.0
# cebula szalotka 0.6956521739130435
# cebulka szalotka 0.6666666666666666
# uszka 0.6153846153846154
# salsa 0.6153846153846154
# szynka lub łopatka 0.6153846153846154
# saletra 0.6666666666666666
# kaszanka 0.625
# natka 0.6153846153846154
# sałatka: 0.625
# serwatka 0.625
# 1 szalotka 0.8888888888888888
# szalotka mała  0.7272727272727273

# %%
# test = "(testing)"
# d = ['(',',',")",'']
# #test.replace('(','')

# for s in d:
#     test = test.replace(s,'')
    
# test

# %%
# names = []
# for name in unique_names:
#     names=names+name.split()

# %%
# d = ['(',',',")"]
# for s in d:
#     #test = test.replace(s,'')

# %%
# for item in setofnames:
#     item = item.replace('(','')
# # setofnames
# Out:
# {'Słoik',
#  '(małe',
#  '(cienkie',
#  'ryby,',
#  'podwawelska',
#  'roslinny',
#  'serowym',
#  'zagęszczający)',
#  'golonka',
#  'roztopione',
#  'tyrolskie',
#  '(moczona)',
#  'wieprzowe',
#  'Wieprzowina',
#  '100g',
#  'łopatki',
#  'konserwa',
#  'Śmietana',
#  'ośmiornica)',
#  'kukurydza,',
#  '4',
#  'hiszpańskie',
#  'podudzi',
#  'garść',
#  'brokuł,',
#  'marynowany',
#  'Gouda',
#  'mączna',
#  'sojowy)',
#  'New',
#  'ryżowego',
#  'plasterki)',
#  'surowego',
#  '(namoczona',
#  'szwarcwaldzka',
#  'małży',
#  '(turówka',
#  'szt.',
#  'diżońska',
#  'wiedeńskie',
#  'kroku',
#  'Do',
#  'grzybków',
#  'francuska',
#  'wyboru',
#  'zawierającej',
#  'lucjan',
#  'szczypiorek',
#  'posypać',
#  'sucharki',
#  'śledzi',
#  'tajskiej',
#  'borówek',
#  'plus',
#  'różnego',
#  'kokosa',
#  'śmietanka',
#  'orientalna',
#  'biała',
#  'melasa',
#  'FARSZ:',
#  'limonek',
#  'tempeh',
#  'czuszka',
#  'krązki',
#  'sojowych',
#  'fraiche',
#  'Muscovado',
#  '(ja',
#  'jaglanej',
#  'małych',
#  'soczyste',
#  'jabłkiem)',
#  'minuty',
#  'paluch',
#  'kiełbasa,',
#  'roszponką',
#  'twarde)',
#  'ozdoby',
#  'noc',
#  'kora',
#  '(twardy,średniej',
#  'garstka',
#  'enoki',
#  'owoce',
#  'trójkolorowa',
#  'jajkiem',
#  'Culinese',
#  'kminek',
#  'kmin',
#  'matjas',
#  'odtłuszczona',
#  'żeberka,',
#  'sielawa',
#  'półrazowego',
#  'kaczki',
#  'płynna',
#  'wielokwiatowy',
#  'Serek',
#  'dorsz',
#  'biała,',
#  'pellati',
#  'pręga',
#  'młoda,',
#  '1',
#  'wytrawnego',
#  'mrożonka',
#  'syrop',
#  'meksykańska',
#  '(niekoniecznie,',
#  'żur',
#  'kajzerka,',
#  'mniej',
#  'matjasy',
#  'oczyszczonego',
#  'wieloziarnista',
#  'pelatti',
#  'duszona',
#  'dobrej',
#  'garści',
#  'sum,',
#  'minut.',
#  ',,',
#  'stołowa',
#  'miodu',
#  'zwykłym',
#  'według',
#  'fasola,',
#  'przypraw',
#  'dorsza',
#  'pizze:',
#  'buła',
#  'otarta',
#  'kasza',
#  'harisy',
#  'Kostki',
#  'kanapki',
#  'okra',
#  '(ugotowany)',
#  '(pojedyncze',
#  'kopru',
#  'pekińska,',
#  'czerstwe',
#  'serka',
#  'kimchi',
#  'marynowanych',
#  'herbata',
#  'Mielone',
#  'kury',
#  'płetwą',
#  'muszatołowa',
#  'pokrojonego',
#  'przez',
#  'mleko,',
#  'Halibuta',
#  '(duże',
#  'potraw',
#  'piórka',
#  'przystrojenia',
#  'sypka',
#  'gotowany',
#  'wykałaczek',
#  'torebka',
#  'od',
#  'papadum',
#  'świeży,',
#  '120gr',
#  'pak',
#  'miętą',
#  'smietanką',
#  'inna',
#  'paparyka',
#  '(na',
#  'majnez',
#  '(szczypior',
#  'mrorzone',
#  'węgierskiego',
#  'nadziane',
#  'małe)',
#  'olbrzymia',
#  'Jakuba)',
#  'utarta',
#  'pomidorki',
#  'wyciśniętej',
#  'panini',
#  'kukurydziana',
#  'ptysiowa',
#  '(małże',
#  'itd)',
#  'ogórków',
#  'zależy',
#  'mleko',
#  'a',
#  'kiszonej',
#  'melisy',
#  'zwykłego',
#  'kapusta',
#  'solnej',
#  'kieliszek',
#  'obniżonej',
#  'koszyk',
#  'karkowy',
#  'alkohol',
#  'młoda)',
#  'marynowana',
#  'grzybów',
#  'jakości',
#  'grilla',
#  'mieszanka',
#  'pieczonych',
#  'kozieradki',
#  'borówka',
#  'masłowej',
#  'marchew,',
#  'Plasterki',
#  'żuru)',
#  'różnokolorowa',
#  'sproszkowany',
#  '(quinoa)',
#  '120g',
#  '(samo',
#  'tostów',
#  'parowki',
#  'srebrzysta',
#  'Olej',
#  'zmiażdżone',
#  'grube',
#  'dziewiczy',
#  'dogów',
#  'wypatroszone',
#  'orkisz',
#  'placki',
#  'rucola-radicchio',
#  'jagnięcina',
#  'rolowania',
#  'watróbka',
#  'portobello',
#  'rambol',
#  'dyniowa:',
#  'zredukowaną',
#  'beszamel',
#  'nieduży',
#  'majeranek',
#  '-',
#  'łuskane',
#  'Babuni',
#  'malutki',
#  'Mun',
#  'lawenda,',
#  'Czosnek,',
#  'surowe',
#  'drożdże',
#  'pikle',
#  'mniejsze',
#  'kamienna',
#  'Rapso',
#  'orechiette',
#  'miękkie)',
#  '(450)',
#  'celofanowym',
#  'porcjowane',
#  'gwiazdki',
#  'się',
#  'oscypki',
#  'ile',
#  'roso',
#  'różowy',
#  'ryżowe',
#  'parówka',
#  'strzępiastej)',
#  'dojrzała',
#  'dyni,',
#  'cząber',
#  '(groszek,',
#  'matiasów',
#  'Czerstwa',
#  'wanilii',
#  'tłuczone',
#  'ukośne',
#  'ghee',
#  'biały)',
#  'sandacz,',
#  'Arborio',
#  'wędzonych',
#  '(podwójne)',
#  '(anchois)',
#  'serca',
#  'nieduże',
#  'okrągłego',
#  'dwukolorowe)',
#  'zielonej',
#  'orzechy',
#  'korniszon',
#  'śmietankowy',
#  'roztrzepane',
#  'pokruszona',
#  'Milti',
#  'I',
#  'gniazdka',
#  'półwytrawne',
#  'koktajlowe,',
#  '(szklany)',
#  'rozkruszony',
#  'gorąco',
#  'ziarnach',
#  'pizzy',
#  'innej',
#  'żółta',
#  'mięta',
#  'madras',
#  'rum',
#  'skórki)',
#  'kupuje',
#  'orzo)',
#  'ananasem',
#  'cebulowe',
#  'gruyère',
#  'quinoa',
#  'węgorz',
#  'błyskawiczna',
#  'chleba,',
#  'przednia',
#  'może',
#  'młotkowany',
#  'carne',
#  'sandacz',
#  'małe',
#  'obciążenia',
#  'plastry)',
#  'pomidorami',
#  'jarzyna',
#  'limonki,',
#  '(puszka',
#  'brukselka',
#  'pełnotłuste',
#  'razowy)',
#  'żelatyny',
#  'parmezanu',
#  'ciecierzyca',
#  'pierścień',
#  'omlet',
#  '25g',
#  'cięty',
#  'tajskie',
#  'wieprzowa,',
#  'dymki)',
#  'winogron',
#  'rozpuszczona',
#  'czerwonych',
#  'ryba)',
#  'proszek',
#  'strąkach',
#  'kuskus',
#  'krótki,',
#  'zioła',
#  'papryki',
#  'mleka',
#  'edamski',
#  '(natka',
#  'solą',
#  'Pinni',
#  'moreli',
#  '100gr',
#  'zalewa:',
#  'mielone',
#  'wanliowy',
#  'kruchego',
#  'pszennego',
#  'taco',
#  'ciepła,',
#  'pędy',
#  'cytyna',
#  'obtoczenia',
#  'krucho-drożdżowe',
#  'chili,',
#  'kakao',
#  'pęczka',
#  'wytrawne',
#  'Fix',
#  'mieszane',
#  '(kulka',
#  'kabaczek',
#  '(np',
#  'papryki)',
#  'Dijon',
#  'kalarepy',
#  'bazylia,',
#  'szczypiorkowo-rzodkiewkowy',
#  'śliwek',
#  'zalewie)',
#  'konfitura',
#  'cieciorki',
#  'pikantna',
#  'ikra',
#  'ziołami',
#  'Pappardelle',
#  '(z',
#  'gatunki',
#  'marchwi',
#  'spody',
#  'Twardy',
#  'minuty.',
#  'zasmażki',
#  'Majeranek',
#  'drobny',
#  'serem',
#  'lukier',
#  'limonka',
#  'ulubiona',
#  'sojowego',
#  'zrazów',
#  'skórki',
#  'meksykańskie',
#  'okonia',
#  'balsamiczna',
#  'proso',
#  'zredukowanej',
#  'lnianego',
#  'podduszone',
#  'botwinki',
#  'średni',
#  'grzyby)',
#  'cola',
#  'podsmażona',
#  'kaki',
#  'paseczki)',
#  'Smaków”',
#  'odciśnięty',
#  'burak',
#  'piekarniku',
#  'wodna',
#  'minikostka',
#  'pieczarkowy',
#  'skrzydła',
#  'ryby',
#  'Boczek',
#  'solonych',
#  '2h)',
#  'cielęce',
#  '(dowolne)',
#  'buraczany',
#  'Podgrzybki',
#  'ale',
#  '(rozmrożony)',
#  'morza',
#  'zapiekania',
#  'sezonowe',
#  'dynii',
#  'dużych',
#  'golonki)',
#  'bajgle',
#  '(najlepsza',
#  'pekińska',
#  'koźlaki,',
#  'wcześniej)',
#  'lniany',
#  'kędzierzawa',
#  'ziarenkami',
#  'kraba',
#  'jeżyny',
#  'pieruszki',
#  'Napoli',
#  'mocno',
#  'łazanki',
#  'greckiego',
#  'topinambur',
#  'wrzątek',
#  'bita',
#  'wino,',
#  'won',
#  'zrazowe',
#  'kalmary',
#  '(36',
#  'balsamiczny:',
#  '360',
#  'macaroni',
#  'kwaśne',
#  'BBQ',
#  'Pieczeni',
#  'Uniwersalna',
#  'Chedar',
#  'sprawiony',
#  'bagietki',
#  'udziec)',
#  'semolina',
#  'kawałek',
#  'różnokolorowe',
#  'kormiszonki',
#  'samorosnąca',
#  'małże',
#  'głowy)',
#  'Kapusta',
#  'shitaki',
#  '(odsączona)',
#  'naturalny',
#  'cukier,',
#  'Pomidor',
#  'dzwonkach',
#  '0%',
#  'pestek)',
#  'puszcze',
#  'noga',
#  '6',
#  '(filety)',
#  'topione',
#  'chrupiącą',
#  'kazamata',
#  'mineralna',
#  'kaczy',
#  'tajska',
#  'szypułek',
#  '(kurczak',
#  'stek',
#  'fenkuł',
#  '(nowozelandzkie)',
#  'ziemniaczana',
#  'niebieska',
#  'jasna',
#  'nerki',
#  'sum',
#  'pół',
#  'raków',
#  'wodzie.',
#  'koperek',
#  'szwardzwaldzka',
#  'salsa',
#  'zwartym',
#  '(buteleczka)',
#  'wstążeczki',
#  '(oscypka)',
#  'zmielony',
#  'barwena',
#  'radicchio,',
#  'czosnkowe:',
#  'main',
#  'macierzanka',
#  'burgera',
#  'fermentowanej',
#  'kulki',
#  'obgotowane',
#  'gorgonzola',
#  'wielkości',
#  'biszkopty',
#  'bucatini',
#  '3',
#  'malutkie',
#  'cukina',
#  'Mięso',
#  'kapusta)',
#  '(świeże',
#  'pełnoziarnista',
#  'niełuskany)',
#  'ptysiowy',
#  'focaccia',
#  'Pietruszka',
#  'sweet',
#  'drobnych',
#  'pieczywa',
#  '(ewentualnie',
#  'starte',
#  'anchovies',
#  'wymoczona',
#  'słonecznika,',
#  'siekanej',
#  '(posiekana)',
#  'jałowiec',
#  'morszczuk)',
#  'Tiger',
#  'Młody',
#  'naturalnej',
#  'kleik',
#  'Treść',
#  'leszcz',
#  'łosoś',
#  '(obrana)',
#  'nadzienie:',
#  'rostbefu',
#  'Śmietanka',
#  'kiełki',
#  'Grzyby',
#  'Bieluch',
#  'sake',
#  '(średnio)',
#  'Chavroux',
#  'ziarnisty',
#  'bambusowa',
#  'schabowe',
#  'soczewica',
#  '250',
#  '(nogi',
#  'puszka',
#  'perliczka',
#  'tłuszczykiem',
#  'porzeczkowy',
#  'Kafiru',
#  'wyboru,',
#  'owczy',
#  'piklowana',
#  '5',
#  'pieczenia,',
#  'pistacjowe',
#  'sznurek',
#  'rodzynkowych)',
#  'mole',
#  'bulionu',
#  'jajka',
#  'posiekane',
#  '(namoczone)',
#  'zwykłe',
#  'francuskie,',
#  'dereń',
#  'glutasól',
#  'kuropatwa',
#  'razowy,',
#  'głowy',
#  'choy',
#  '(lekko',
#  'niewielki',
#  '(w',
#  'ziarno',
#  'czosnkowy',
#  'bazyliowa',
#  'wywar',
#  'strąk',
#  'seler,',
#  '35%',
#  'fasolą',
#  'arkusz',
#  'gorąca,',
#  'szczypioru,',
#  '(surowy)',
#  'zupka',
#  'brie',
#  'rzodkiewki',
#  'bakłażan',
#  'karmel',
#  'otręby',
#  'zimne',
#  'ogon',
#  'kolorowe',
#  'baby',
#  'tajskiego',
#  'trzech',
#  'Rama',
#  'cielęca',
#  'wiśniowy',
#  'francuskiej',
#  'majonezu',
#  'ulubionych',
#  'łopatka)',
#  'pieczarki,',
#  'jagnięciny',
#  'niebieską',
#  'świderki',
#  'wymieszać.',
#  'łodyga',
#  'tostowe',
#  '12%',
#  'porter',
#  'dębolistna',
#  'wyciśnięty',
#  'tortilli',
#  'na',
#  'musztada',
#  'miso',
#  'skorupkach',
#  'odsączona)',
#  'myśliwska',
#  'soczysta',
#  'wołowina',
#  'opieńki,',
#  'kości,',
#  'sałatka',
#  'skręcana)',
#  'mak',
#  '(5',
#  'Gnocchi',
#  'hawajska',
#  'kropli',
#  'karczochów',
#  'frankfurterki',
#  'Masło',
#  'koniak',
#  'żytniej',
#  'kaparami',
#  'Mały',
#  'udziec',
#  'plastrach',
#  'pietruszka',
#  'posypania',
#  'greckiego)',
#  'szparagowa',
#  'lina',
#  'połówka',
#  'słodka',
#  'bazylią',
#  'kostke',
#  'twarogowa:',
#  'chilli,',
#  'zielona',
#  'orzechy,',
#  'Wernicchelli',
#  'ziemniaczki',
#  'laurowy',
#  'Chili',
#  '(błyskawiczna)',
#  'cienkich',
#  'ogonówka',
#  'kminek,',
#  'kopytka',
#  'Dodać',
#  'Eros',
#  'kwiatów',
#  'Łosoś',
#  '(extra',
#  'literki',
#  'Batat',
#  'kartofel',
#  'mandarynki',
#  'Mlekovity',
#  'czarnymi',
#  'św.',
#  'podłużna',
#  'kafir',
#  'kręgosłup,',
#  'sałatka:',
#  'chuda',
#  'shitake:',
#  'kuchni',
#  'piquillo',
#  'inny)',
#  'byc',
#  'kurczka',
#  'gulaszowe',
#  'stopione',
#  'indyczej',
#  'sucha',
#  'szynką',
#  'cytryna',
#  '(odcedzone)',
#  'sznyclówka',
#  'papai',
#  '(około',
#  'paryska',
#  'wolnowybiegowy',
#  'kości)',
#  'vergine',
#  '(mogą',
#  'tarce',
#  'homar',
#  '40',
#  'strzępiasta)',
#  'bigos',
#  'kalarepka',
#  'panir',
#  'test',
#  'środek',
#  'salami',
#  'uniwersalny',
#  'Czarna',
#  'papryczka)',
#  'Sułtańskie',
#  '(zmielona)',
#  'jelita',
#  'twarogu',
#  'śniadaniowego',
#  'okrągły',
#  'bulionowa',
#  '(duży',
#  'jarzynowa',
#  'chia',
#  'pszenny,',
#  'słone',
#  '0,5',
#  'gulasz:',
#  'peklowania',
#  '(16',
#  'frytki',
#  'Dorsz',
#  'mniejszy)',
#  'chude',
#  'wegański',
#  'szynka)',
#  'banana',
#  'linguine',
#  'świeżych',
#  'papryczek',
#  '(słodkie',
#  '650',
#  'jęczmienne',
#  'tony',
#  'razowiec-skórka-',
#  'sałała',
#  'ugotowanych',
#  'siemienia',
#  'kiełbasa',
#  'przepiórcze',
#  'krople',
#  'Polędwiczka',
#  'musztardowca',
#  'kostki',
#  'warzywami',
#  'Kasia',
#  '(przekrojonego',
#  'bezlaktozowe,',
#  'tacos',
#  'wołowe',
#  'sypko',
#  'macowa',
#  'orzechowy',
#  'czarnego',
#  'parmeńska)',
#  'bataty',
#  'sandacza',
#  'skóra',
#  'otarka',
#  'sól',
#  'również',
#  'świeżego)',
#  'piniowe,',
#  '(dzwonko,',
#  '(kokardki)',
#  'klarowane',
#  'ziemniaki',
#  'związania',
#  'rzymska)',
#  'główki',
#  'świeży',
#  'Worcestershire',
#  '125',
#  'kluski',
#  'kromki',
#  'medaliony',
#  'naciowe',
#  'Jajko',
#  'Grana',
#  'basmati,',
#  'wieloziarnisty,',
#  'wołowego',
#  'słoika)',
#  'zapiekanek',
#  'farsz',
#  'wędzonka',
#  'pszennej',
#  'Almette',
#  'mięsa',
#  'żytni,',
#  'baklażan',
#  'rama',
#  'wrzątku',
#  'nieparzony',
#  'polskie',
#  'podwędzana',
#  'kapary',
#  'Młoda',
#  'groszku',
#  'tilapia',
#  'ziarenek',
#  'ementalera',
#  'natartych',
#  'małą',
#  'bagietka',
#  'Cukier',
#  'wędzony,',
#  'skwarki',
#  'dużą',
#  'fioletowe',
#  'naturalnego',
#  'mrożonego)',
#  'szczypta',
#  'brzoskwini',
#  '(np.',
#  'ukraiński',
#  'tortelini',
#  'cukinie',
#  'brązowego',
#  'mozzarella,',
#  'camembert',
#  'golonki',
#  'małym',
#  'sznycel',
#  'ostrygowy',
#  'jałowcowa)',
#  'ekspandowany',
#  'kminu',
#  'surowy,',
#  'dla',
#  'Creme',
#  'pomidorowa',
#  'płatkach',
#  'upieczeniu',
#  'ostry',
#  'żytnie',
#  'Zapte',
#  'smalec',
#  '(wstążki)',
#  'paście',
#  'wyłuskane',
#  'zalewy',
#  'spring',
#  'wafle',
#  'krucha',
#  'pomidorków',
#  'kebab',
#  'pierwszego',
#  'skrojona',
#  'fenkułu',
#  '„Pięć',
#  'gałązka',
#  'kolby)',
#  'makrele',
#  'mata',
#  'słonecznikowy',
#  'wody',
#  'Kartupeļi',
#  'zwykłej',
#  'muszkatałowa',
#  'orzechowego',
#  'ŚWIDRY',
#  'rucola',
#  'paseczki',
#  'głową',
#  'pekińskiej',
#  'bazyliowe',
#  'owoce:',
#  'caneloni',
#  'łuskany',
#  'Zakwas',
#  'gęś',
#  'twardego',
#  'prostokąty',
#  'gorącej',
#  'szybko',
#  'półostra',
#  'arachidowych',
#  'proszku,',
#  '(sucha)',
#  'drylowane',
#  'smażonych',
#  'zblanszowany)',
#  '(ok.',
#  'ceramiczne',
#  'kostkę)',
#  'Rolls',
#  'wrzącej',
#  'maślaki,',
#  'kajeński',
#  'brokuł',
#  'kurki)',
#  'siekany',
#  'metka',
#  'cząstki',
#  'steki)',
#  'radicchio',
#  '½',
#  'młody',
#  'Cebulki',
#  'utłuczone',
#  'wymieszać',
#  'korzeniowy,',
#  'tradycyjna',
#  'sól,',
#  'kapusty',
#  'roztarta',
#  'lepiej',
#  'wątroba',
#  '0.5',
#  'szpinakowe',
#  'makaronu',
#  'kaszanki,',
#  'Soda',
#  'mimolet,',
#  'sambal',
#  'wypestkowane',
#  'folia',
#  'muszelki',
#  'przyprawy',
#  'Ogórki',
#  'papaja',
#  'M@M',
#  'półplasterki)',
#  'rzymskiej',
#  '(polędwica',
#  'pimento',
#  'bałkański',
#  'sopocka',
#  'makreli',
#  'estragonowy',
#  'likier',
#  'tajskiego)',
#  'kolendra',
#  'drobiowy',
#  'gramów',
#  'Ketchup',
#  'Czosnkowy',
#  'gorczycą',
#  'jogurty',
#  'cztery',
#  'nilowego',
#  'czerstwej',
#  ...}

# %%
def Clear(names):
    n=[]
    for name in names:
        a=re.sub('[^a-ząćęółżźśń ]+', '', name)
        n.append(a)
    return n
names = Clear(names)

# %%
df_uni =pd.DataFrame(columns=['name','count'])
setofnames = set(names)
for i,name in enumerate(setofnames):
    a = names.count(name)
    df_uni.loc[i] = [name, a]

# %%
df_uni.sort_values('count', ascending=0)
# Out:
#              name count
# 1688            z  1146
# 0                   975
# 2543            w   657
# 3512          lub   589
# 1571           do   365
# 1711          ser   318
# 3609      makaron   209
# 3441     kurczaka   201
# 1563        mięso   198
# 944       papryka   197
# 1309            i   197
# 1872          bez   196
# 3528     czerwona   161
# 1122           np   158
# 667        świeży   156
# 2041      suszone   148
# 1437            g   144
# 2329       cebula   126
# 1788     pomidory   125
# 540            na   122
# 1201       puszki   117
# 2784    pokrojona   116
# 3196         mała   114
# 3442        chili   111
# 1524        filet   109
# 1756       filety   107
# 567       zielona   106
# 1134        kilka   103
# 1157       świeże   103
# 1795       kostkę   100
# ...           ...   ...
# 1797       mięsem     1
# 1799       kolbie     1
# 1800     owalnego     1
# 1803      stirfry     1
# 1786    drobiowym     1
# 1805    serdelowa     1
# 1807  truskawkowy     1
# 1808     szczypty     1
# 1809     pakowane     1
# 1810   skrzydełko     1
# 1811     nagietka     1
# 1790  przesmażona     1
# 1782        koźle     1
# 1740       jarzyn     1
# 1762   środkowego     1
# 1742   orzechówka     1
# 1744    ostudzone     1
# 1749    normalnej     1
# 1751       jasiek     1
# 1755      alibuta     1
# 1760    orgonzola     1
# 1764         dość     1
# 1781     łagodnej     1
# 1767     armeńska     1
# 1768       filetu     1
# 1776         djon     1
# 1777        royal     1
# 1778    twarogowa     1
# 1779   buteleczka     1
# 3797     olejowej     1
#
# [3798 rows x 2 columns]

# %%
# re.sub('[^A-Za-z0-9]+', '', mystring)

# %%
# stop_words = ["", "z", "w", "lub", "do", "i", "bez", "-", "świeży", "np.", "na", "g", "mała", "np",
#              "suszone", "puszki", "pokrojona", "czerwona", "świeże", "zielona", "kilka", "kostkę",
#              "pokrojone", "biała", "ze", "żółty", "mały", "świeża", "pęczek", "dekoracja",
#              "duże", "mrożone", "knorr"]
